# %% [markdown]
# ## Pre-Tokenizer
# Tokenize SMILES (Simplified Molecular-Input Line-Entry System) into units.

# %%
#hide
from nbdev.showdoc import *

# %%
def atomwise_tokenizer(smi, exclusive_tokens = None):
    """
    Tokenize a SMILES molecule at atom-level:
        (1) 'Br' and 'Cl' are two-character tokens
        (2) Symbols with bracket are considered as tokens
    exclusive_tokens: A list of specifical symbols with bracket you want to keep. e.g., ['[C@@H]', '[nH]'].
    Other symbols with bracket will be replaced by '[UNK]'. default is `None`.
    """
    import re
    pattern =  "(\[[^\]]+]|Br?|Cl?|N|O|S|P|F|I|b|c|n|o|s|p|\(|\)|\.|=|#|-|\+|\\\\|\/|:|~|@|\?|>|\*|\$|\%[0-9]{2}|[0-9])"
    regex = re.compile(pattern)
    tokens = [token for token in regex.findall(smi)]

    if exclusive_tokens:
        for i, tok in enumerate(tokens):
            if tok.startswith('['):
                if tok not in exclusive_tokens:
                    tokens[i] = '[UNK]'
    return tokens

# %%
def kmer_tokenizer(smiles, ngram=4, stride=1, remove_last = False, exclusive_tokens = None):
    units = atomwise_tokenizer(smiles, exclusive_tokens = exclusive_tokens) #collect all the atom-wise tokens from the SMILES
    if ngram == 1:
        tokens = units
    else:
        tokens = [tokens_to_mer(units[i:i+ngram]) for i in range(0, len(units), stride) if len(units[i:i+ngram]) == ngram]

    if remove_last:
        if len(tokens[-1]) < ngram: #truncate last whole k-mer if the length of the last k-mers is less than ngram.
            tokens = tokens[:-1]
    return tokens

def tokens_to_mer(toks):
    return ''.join(toks)

# %% [markdown]
# Tokenize a SMILES string on atom-level.

# %%
f = open("C:/Users/Administrator/moses.smi.txt",'r')
smii = f.readlines()

print(smii[:5])
tokss=[atomwise_tokenizer(smi) for smi in smii]
print(tokss[:5])
# Out:
# ['CCCS(=O)c1ccc2[nH]c(=NC(=O)OC)[nH]c2c1\n', 'CC(C)(C)C(=O)C(Oc1ccc(Cl)cc1)n1ccnc1\n', 'Cc1c(Cl)cccc1Nc1ncccc1C(=O)OCC(O)CO\n', 'Cn1cnc2c1c(=O)n(CC(O)CO)c(=O)n2C\n', 'CC1Oc2ccc(Cl)cc2N(CC(O)CO)C1=O\n']
# [['C', 'C', 'C', 'S', '(', '=', 'O', ')', 'c', '1', 'c', 'c', 'c', '2', '[nH]', 'c', '(', '=', 'N', 'C', '(', '=', 'O', ')', 'O', 'C', ')', '[nH]', 'c', '2', 'c', '1'], ['C', 'C', '(', 'C', ')', '(', 'C', ')', 'C', '(', '=', 'O', ')', 'C', '(', 'O', 'c', '1', 'c', 'c', 'c', '(', 'Cl', ')', 'c', 'c', '1', ')', 'n', '1', 'c', 'c', 'n', 'c', '1'], ['C', 'c', '1', 'c', '(', 'Cl', ')', 'c', 'c', 'c', 'c', '1', 'N', 'c', '1', 'n', 'c', 'c', 'c', 'c', '1', 'C', '(', '=', 'O', ')', 'O', 'C', 'C', '(', 'O', ')', 'C', 'O'], ['C', 'n', '1', 'c', 'n', 'c', '2', 'c', '1', 'c', '(', '=', 'O', ')', 'n', '(', 'C', 'C', '(', 'O', ')', 'C', 'O', ')', 'c', '(', '=', 'O', ')', 'n', '2', 'C'], ['C', 'C', '1', 'O', 'c', '2', 'c', 'c', 'c', '(', 'Cl', ')', 'c', 'c', '2', 'N', '(', 'C', 'C', '(', 'O', ')', 'C', 'O', ')', 'C', '1', '=', 'O']]

# %%
smi = 'CC[N+](C)(C)Cc1ccccc1Br'
toks = atomwise_tokenizer(smi)
print(toks)
# Out:
# ['C', 'C', '[N+]', '(', 'C', ')', '(', 'C', ')', 'C', 'c', '1', 'c', 'c', 'c', 'c', 'c', '1', 'Br']

# %%
#hide
atomwise_tokenizer('ABrBCD>>[dum]dumcobrclCl[Br] %11')
# Out:
# ['Br', 'B', 'C', '>', '>', '[dum]', 'c', 'o', 'b', 'c', 'Cl', '[Br]', '%11']

# %%
sep_tokens = ['[C@@H]', '[C@@]']
smi = 'CC(C)C[C@@H]1N2C(=O)[C@](NC(=O)[C@H]3CN(C)[C@@H]4Cc5c(Br)[nH]c6cccc(C4=C3)c56)(O[C@@]2(O)[C@@H]7CCCN7C1=O)C(C)C'
toks = atomwise_tokenizer(smi, exclusive_tokens=sep_tokens)
print(toks)
# Out:
# ['C', 'C', '(', 'C', ')', 'C', '[C@@H]', '1', 'N', '2', 'C', '(', '=', 'O', ')', '[UNK]', '(', 'N', 'C', '(', '=', 'O', ')', '[UNK]', '3', 'C', 'N', '(', 'C', ')', '[C@@H]', '4', 'C', 'c', '5', 'c', '(', 'Br', ')', '[UNK]', 'c', '6', 'c', 'c', 'c', 'c', '(', 'C', '4', '=', 'C', '3', ')', 'c', '5', '6', ')', '(', 'O', '[C@@]', '2', '(', 'O', ')', '[C@@H]', '7', 'C', 'C', 'C', 'N', '7', 'C', '1', '=', 'O', ')', 'C', '(', 'C', ')', 'C']

# %%
#hide
seq = 'ABCDTTDSE'
toks = atomwise_tokenizer(seq)
print(toks)
# Out:
# ['B', 'C', 'S']

# %%
smi = 'CC[N+](C)(C)Cc1ccccc1Br'
toks = kmer_tokenizer(smi, ngram=4)
print(toks)
# Out:
# ['CC[N+](', 'C[N+](C', '[N+](C)', '(C)(', 'C)(C', ')(C)', '(C)C', 'C)Cc', ')Cc1', 'Cc1c', 'c1cc', '1ccc', 'cccc', 'cccc', 'ccc1', 'cc1Br']

# %%
#smi = 'CC[N+](C)(C)Cc1ccccc1Br'


tokss=[kmer_tokenizer(smi,ngram=4) for smi in smii]
print(tokss[:5])
# Out:
# [['CCCS', 'CCS(', 'CS(=', 'S(=O', '(=O)', '=O)c', 'O)c1', ')c1c', 'c1cc', '1ccc', 'ccc2', 'cc2[nH]', 'c2[nH]c', '2[nH]c(', '[nH]c(=', 'c(=N', '(=NC', '=NC(', 'NC(=', 'C(=O', '(=O)', '=O)O', 'O)OC', ')OC)', 'OC)[nH]', 'C)[nH]c', ')[nH]c2', '[nH]c2c', 'c2c1'], ['CC(C', 'C(C)', '(C)(', 'C)(C', ')(C)', '(C)C', 'C)C(', ')C(=', 'C(=O', '(=O)', '=O)C', 'O)C(', ')C(O', 'C(Oc', '(Oc1', 'Oc1c', 'c1cc', '1ccc', 'ccc(', 'cc(Cl', 'c(Cl)', '(Cl)c', 'Cl)cc', ')cc1', 'cc1)', 'c1)n', '1)n1', ')n1c', 'n1cc', '1ccn', 'ccnc', 'cnc1'], ['Cc1c', 'c1c(', '1c(Cl', 'c(Cl)', '(Cl)c', 'Cl)cc', ')ccc', 'cccc', 'ccc1', 'cc1N', 'c1Nc', '1Nc1', 'Nc1n', 'c1nc', '1ncc', 'nccc', 'cccc', 'ccc1', 'cc1C', 'c1C(', '1C(=', 'C(=O', '(=O)', '=O)O', 'O)OC', ')OCC', 'OCC(', 'CC(O', 'C(O)', '(O)C', 'O)CO'], ['Cn1c', 'n1cn', '1cnc', 'cnc2', 'nc2c', 'c2c1', '2c1c', 'c1c(', '1c(=', 'c(=O', '(=O)', '=O)n', 'O)n(', ')n(C', 'n(CC', '(CC(', 'CC(O', 'C(O)', '(O)C', 'O)CO', ')CO)', 'CO)c', 'O)c(', ')c(=', 'c(=O', '(=O)', '=O)n', 'O)n2', ')n2C'], ['CC1O', 'C1Oc', '1Oc2', 'Oc2c', 'c2cc', '2ccc', 'ccc(', 'cc(Cl', 'c(Cl)', '(Cl)c', 'Cl)cc', ')cc2', 'cc2N', 'c2N(', '2N(C', 'N(CC', '(CC(', 'CC(O', 'C(O)', '(O)C', 'O)CO', ')CO)', 'CO)C', 'O)C1', ')C1=', 'C1=O']]

# %%
#!pip install SmilesPE
# Out:
# Collecting SmilesPE
#   Downloading SmilesPE-0.0.3-py3-none-any.whl (15 kB)
# Requirement already satisfied: fastprogress in c:\users\administrator\anaconda3\lib\site-packages (from SmilesPE) (1.0.3)
# Requirement already satisfied: gensim in c:\users\administrator\anaconda3\lib\site-packages (from SmilesPE) (4.1.2)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\administrator\anaconda3\lib\site-packages (from gensim->SmilesPE) (5.2.1)
# Requirement already satisfied: scipy>=0.18.1 in c:\users\administrator\anaconda3\lib\site-packages (from gensim->SmilesPE) (1.7.3)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\administrator\anaconda3\lib\site-packages (from gensim->SmilesPE) (1.21.5)
# Installing collected packages: SmilesPE
# Successfully installed SmilesPE-0.0.3

# %% [markdown]
# ## Pre-trained SmilesPE Tokenizer

# %%
smiii=smii[:10]
smiii
# Out:
# ['CCCS(=O)c1ccc2[nH]c(=NC(=O)OC)[nH]c2c1\n',
#  'CC(C)(C)C(=O)C(Oc1ccc(Cl)cc1)n1ccnc1\n',
#  'Cc1c(Cl)cccc1Nc1ncccc1C(=O)OCC(O)CO\n',
#  'Cn1cnc2c1c(=O)n(CC(O)CO)c(=O)n2C\n',
#  'CC1Oc2ccc(Cl)cc2N(CC(O)CO)C1=O\n',
#  'CCOC(=O)c1cncn1C1CCCc2ccccc21\n',
#  'COc1ccccc1OC(=O)Oc1ccccc1OC\n',
#  'O=C1Nc2ccc(Cl)cc2C(c2ccccc2Cl)=NC1O\n',
#  'CN1C(=O)C(O)N=C(c2ccccc2Cl)c2cc(Cl)ccc21\n',
#  'CCC(=O)c1ccc(OCC(O)CO)c(OC)c1\n']

# %%
import codecs
from SmilesPE.tokenizer import *

spe_vob= codecs.open('C:/Users/Administrator/SPE_ChEMBL.txt')
spe = SPE_Tokenizer(spe_vob)

for smi in smiii:
    tokens = spe.tokenize(smi)
    print(tokens.split()) #split(); 공백을 기준으로 분리
# Out:
# ['CCC', 'S(=O)', 'c1ccc2[nH]', 'c(', '=', 'NC(=O)', 'OC)', '[nH]c2c1']
# ['CC(C)(C)', 'C(=O)C(', 'Oc1ccc(', 'Cl)cc1)', 'n1cc', 'nc1']
# ['Cc1c(Cl)', 'cccc1', 'Nc1n', 'cccc1', 'C(=O)OCC', '(O)', 'CO']
# ['Cn1', 'cnc2', 'c1c(=O)', 'n(', 'CC(O)', 'CO)', 'c(=O)n2', 'C']
# ['CC1', 'O', 'c2ccc(Cl)cc2', 'N(', 'CC(O)', 'CO)', 'C1=O']
# ['CCOC(=O)', 'c1cn', 'cn1', 'C1', 'CCC', 'c2ccccc21']
# ['COc1ccccc1', 'O', 'C(=O)O', 'c1ccccc1', 'OC']
# ['O=C1N', 'c2ccc(Cl)cc2', 'C(', 'c2ccccc2Cl)', '=N', 'C1O']
# ['CN1C(=O)', 'C(O)', 'N=C(', 'c2ccccc2Cl)', 'c2cc(Cl)cc', 'c21']
# ['CCC(=O)', 'c1ccc(OCC', '(O)', 'CO)', 'c(OC)c1']

# %% [markdown]
# ## SmilesPE Learner
# Train a SmilesPE learner

# %%
#!pip install fastprogress

# %%
#export

import os
import sys
import inspect
import copy
import io
import warnings
import re
from collections import defaultdict, Counter
from fastprogress.fastprogress import master_bar, progress_bar

from SmilesPE.pretokenizer import *

def randomize_smiles(smiles):
    """
    Require `RDKit` library. 
    
    Generate a new SMILES string for the same molecule.
    
    Perform a randomization of a SMILES string must be RDKit sanitizable.
    """
    import random
    import numpy as np
    from rdkit import Chem
    
    m = Chem.MolFromSmiles(smiles)
    ans = list(range(m.GetNumAtoms()))
    np.random.shuffle(ans)
    nm = Chem.RenumberAtoms(m,ans)
    return Chem.MolToSmiles(nm, canonical=False, isomericSmiles=True, kekuleSmiles=False)

def corpus_augment(infile, outdir, cycles): #randomize_smiles로 데이터 augmentation
    '''
    infile: line separated SMILES file
    outdir: directory to save the  augmented SMILE file. 
        Each round of augmentation will save as a separated file, named as `infile_Ri`. 
    cycles: number of rounds for SMILES augmentation
    '''
    if cycles <= 0:
        raise ValueError("Invalid option,  cycle should be larger than 0")
    
    with open(infile, "r") as ins:
        can_smiles = []
        for line in ins:
            can_smiles.append(line.split('\n')[0])
    
    fname = os.path.basename(infile).split('.')[0]
    ftype = os.path.basename(infile).split('.')[1]
    
    mb = master_bar(range(cycles))
    for i in mb:
        with open(f'{outdir}/{fname}_R{i}.{ftype}', 'a') as outfile:
            for smi in progress_bar(can_smiles, parent=mb):
                randomized_smi = randomize_smiles(smi)
                outfile.write(randomized_smi + '\n')

def get_vocabulary(smiles, augmentation=0, exclusive_tokens = False): 
    #input된 smiles를 count하고, 지정된 횟수만큼 augmentation 하고, 
    #atomwise_tokenizer함수로 토큰화하고 해당 토큰을 카운트하고, 딕셔너리 형태로 반환함.
    """Read text and return dictionary that encodes vocabulary
    """
    print('Counting SMILES...')
    vocab = Counter()
    
    for i, smi in enumerate(smiles):
        vocab[smi] += 1
    
    print(f'{len(vocab)} unique Canonical SMILES')
    
    if augmentation>0:
        print(f'Augmenting SMILES...({augmentation} times)')
        mb = master_bar(range(augmentation))
        for i in mb:        
            for smi in progress_bar(smiles, parent=mb):
                randomized_smi = randomize_smiles(smi)
                vocab[randomized_smi] += 1
    
        print(f'{len(vocab)} unique SMILES (Canonical + Augmented)')
    return dict([(tuple(atomwise_tokenizer(x)) ,y) for (x,y) in vocab.items()])

def update_pair_statistics(pair, changed, stats, indices):
    #자주 등장하는 smiles pair를 하나의 문자로
    #pair가 포함된 문자열의 빈도수와 인덱스를 업데이트함.
    """Minimally update the indices and frequency of symbol pairs
    if we merge a pair of symbols, only pairs that overlap with occurrences
    of this pair are affected, and need to be updated.
    """
    stats[pair] = 0
    indices[pair] = defaultdict(int)
    first, second = pair
    new_pair = first+second
    for j, word, old_word, freq in changed:

        # find all instances of pair, and update frequency/indices around it
        i = 0
        while True:
            # find first symbol
            try:
                i = old_word.index(first, i)
            except ValueError:
                break
            # if first symbol is followed by second symbol, we've found an occurrence of pair (old_word[i:i+2])
            if i < len(old_word)-1 and old_word[i+1] == second:
                # assuming a symbol sequence "A B C", if "B C" is merged, reduce the frequency of "A B"
                if i:
                    prev = old_word[i-1:i+1]
                    stats[prev] -= freq
                    indices[prev][j] -= 1
                if i < len(old_word)-2:
                    # assuming a symbol sequence "A B C B", if "B C" is merged, reduce the frequency of "C B".
                    # however, skip this if the sequence is A B C B C, because the frequency of "C B" will be reduced by the previous code block
                    if old_word[i+2] != first or i >= len(old_word)-3 or old_word[i+3] != second:
                        nex = old_word[i+1:i+3]
                        stats[nex] -= freq
                        indices[nex][j] -= 1
                i += 2
            else:
                i += 1

        i = 0
        while True:
            try:
                # find new pair
                i = word.index(new_pair, i)
            except ValueError:
                break
            # assuming a symbol sequence "A BC D", if "B C" is merged, increase the frequency of "A BC"
            if i:
                prev = word[i-1:i+1]
                stats[prev] += freq
                indices[prev][j] += 1
            # assuming a symbol sequence "A BC B", if "B C" is merged, increase the frequency of "BC B"
            # however, if the sequence is A BC BC, skip this step because the count of "BC BC" will be incremented by the previous code block
            if i < len(word)-1 and word[i+1] != new_pair:
                nex = word[i:i+2]
                stats[nex] += freq
                indices[nex][j] += 1
            i += 1
            
def get_pair_statistics(vocab):#pair의 빈도 count, index 생성
    """Count frequency of all symbol pairs, and create index"""

    # data structure of pair frequencies
    stats = defaultdict(int)

    #index from pairs to words
    indices = defaultdict(lambda: defaultdict(int))
    
    for i, (word, freq) in enumerate(progress_bar(vocab)):
        prev_char = word[0]
        for char in word[1:]:
            stats[prev_char, char] += freq
            indices[prev_char, char][i] += 1
            prev_char = char

    return stats, indices

# %%
def replace_pair(pair, vocab, indices):
    """Replace all occurrences of a symbol pair ('A', 'B') with a new symbol 'AB'"""
    first, second = pair
    pair_str = ''.join(pair)
    pair_str = pair_str.replace('\\','\\\\')
    changes = []
    pattern = re.compile(r'(?<!\S)' + re.escape(first + ' ' + second) + r'(?!\S)')
    if sys.version_info < (3, 0):
        iterator = indices[pair].iteritems()
    else:
        iterator = indices[pair].items()
    for j, freq in iterator:
        if freq < 1:
            continue
        word, freq = vocab[j]
        new_word = ' '.join(word)
        new_word = pattern.sub(pair_str, new_word)
        new_word = tuple(new_word.split(' '))

        vocab[j] = (new_word, freq)
        changes.append((j, new_word, word, freq))

    return changes

def prune_stats(stats, big_stats, threshold): #속도 높이기 위해 pair의 빈도 가지치기
    """Prune statistics dict for efficiency of max()
    The frequency of a symbol pair never increases, so pruning is generally safe
    (until we the most frequent pair is less frequent than a pair we previously pruned)
    big_stats keeps full statistics for when we need to access pruned items
    """
    for item,freq in list(stats.items()):
        if freq < threshold:
            del stats[item]
            if freq < 0:
                big_stats[item] += freq
            else:
                big_stats[item] = freq

def learn_SPE(infile, outfile, num_symbols, min_frequency=2, augmentation=0, verbose=False, total_symbols=False):
    """
    Learn num_symbols SPE operations from infile and write to outfile.
    
    *infile*: a list of SMILES
    
    *num_symbols*: maximum total number of SPE symbols 
    
    *min_frequency*: the minimum frequency of SPE symbols appears.
    
    *augmentation*: times of SMILES augmentation
    
    *verbose*: if True, print the merging process
    
    *total_symbols*: if True; the maximum total of SPE symbols = num_symbols - number of atom-level tokens
    """
    

    
    vocab = get_vocabulary(infile, augmentation=augmentation)
    sorted_vocab = sorted(vocab.items(), key=lambda x: x[1], reverse=True)
    
    print('Gettting Pair Statistics')
    stats, indices = get_pair_statistics(sorted_vocab)
    big_stats = copy.deepcopy(stats)

    if total_symbols:
        uniq_char = set()
        for word in vocab:
            for char in word:
                uniq_char.add(char)
        sys.stderr.write(f'Number of unique characters & Reducing number of merge operations by: {len(uniq_char)}\n')
        sys.stderr.write(f'Unique characters: {(uniq_char)}\n')
        num_symbols -= len(uniq_char)
                    
    # threshold is inspired by Zipfian assumption, but should only affect speed
    threshold = max(stats.values()) / 10
    for i in range(num_symbols):
        if stats:
            most_frequent = max(stats, key=lambda x: (stats[x], x))

        # we probably missed the best pair because of pruning; go back to full statistics
        if not stats or (i and stats[most_frequent] < threshold):
            prune_stats(stats, big_stats, threshold)
            stats = copy.deepcopy(big_stats)
            most_frequent = max(stats, key=lambda x: (stats[x], x))
            # threshold is inspired by Zipfian assumption, but should only affect speed
            threshold = stats[most_frequent] * i/(i+10000.0)
            prune_stats(stats, big_stats, threshold)

        if stats[most_frequent] < min_frequency:
            sys.stderr.write('no pair has frequency >= {0}. Stopping\n'.format(min_frequency))
            break
        
        if verbose:
            sys.stderr.write('pair {0}: {1} {2} -> {1}{2} (frequency {3})\n'.format(i, most_frequent[0], most_frequent[1], stats[most_frequent]))
        outfile.write('{0} {1}\n'.format(*most_frequent))
        changes = replace_pair(most_frequent, sorted_vocab, indices)
        update_pair_statistics(most_frequent, changes, stats, indices)
        stats[most_frequent] = 0
        if not i % 100:
            prune_stats(stats, big_stats, threshold)

# %% [markdown]
# train_SPE

# %%
import codecs
from SmilesPE.learner import *

# %%
file_name = "C:/Users/Administrator/moses.smi.txt"

with open(file_name, "r") as ins:
    SMILES = []
    for line in ins:
        SMILES.append(line.split('\n')[0])
print('Number of SMILES:', len(SMILES))
# Out:
# Number of SMILES: 1584663

# %% [markdown]
# ## Training
# input: a list of SMILES
#
# output: the file to save the learned vocabulary.
#
# num_symbols: maximum total number of SPE symbols, set to 30,000
#
# min_frequency: the minimum frequency of SPE symbols appears, set to 2,000.
#
# augmentation: times of SMILES augmentation, set to 1. The final data set is ~2 times larger than the original one.
#
# verbose: if True, print the merging process
#
# total_symbols: if True; the maximum total of SPE symbols = num_symbols - number of atom-level token.

# %%
# !pip install rdkit
# Out:
# Collecting rdkit
#   Downloading rdkit-2022.9.5-cp37-cp37m-win_amd64.whl (20.5 MB)
#      --------------------------------------- 20.5/20.5 MB 13.4 MB/s eta 0:00:00
# Requirement already satisfied: Pillow in c:\users\administrator\anaconda3\lib\site-packages (from rdkit) (9.3.0)
# Requirement already satisfied: numpy in c:\users\administrator\anaconda3\lib\site-packages (from rdkit) (1.21.5)
# Installing collected packages: rdkit
# Successfully installed rdkit-2022.9.5

# %%
# %%time
output = codecs.open('../SPE_output.txt', 'w')
learn_SPE(SMILES, output, 30000, min_frequency=2000, augmentation=1, verbose=True, total_symbols=True)
# Out:
# Counting SMILES...
# 1584663 unique Canonical SMILES
# Augmenting SMILES...(1 times)
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# 3159633 unique SMILES (Canonical + Augmented)
# Gettting Pair Statistics
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='3159633' class='' max='3159633' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [3159633/3159633 00:52&lt;00:00]
#     </div>
# Number of unique characters & Reducing number of merge operations by: 25
# Unique characters: {'n', '7', 'O', 'S', '1', 'F', '=', '(', '3', 'N', '6', 'Cl', '#', 'o', '[H]', '-', 'c', 'Br', '4', '5', '2', 's', 'C', '[nH]', ')'}
# pair 0: c c -> cc (frequency 11709857)
# pair 1: C C -> CC (frequency 5874847)
# pair 2: c 1 -> c1 (frequency 4895619)
# pair 3: ( C -> (C (frequency 4233604)
# pair 4: = O -> =O (frequency 4093346)
# pair 5: =O ) -> =O) (frequency 3823709)
# pair 6: ( =O) -> (=O) (frequency 2978411)
# pair 7: c 2 -> c2 (frequency 2970701)
# pair 8: c ( -> c( (frequency 2119276)
# pair 9: (C ) -> (C) (frequency 2116033)
# pair 10: c1 cc -> c1cc (frequency 1830669)
# pair 11: N C -> NC (frequency 1452832)
# pair 12: ) cc -> )cc (frequency 1429503)
# pair 13: c2 cc -> c2cc (frequency 1100286)
# pair 14: 2 ) -> 2) (frequency 986195)
# pair 15: c 3 -> c3 (frequency 897909)
# pair 16: O C -> OC (frequency 860289)
# pair 17: (=O) N -> (=O)N (frequency 858618)
# pair 18: CC C -> CCC (frequency 821381)
# pair 19: n 1 -> n1 (frequency 820386)
# pair 20: c (C -> c(C (frequency 700410)
# pair 21: ( N -> (N (frequency 626534)
# pair 22: c n -> cn (frequency 602924)
# pair 23: ) C -> )C (frequency 591081)
# pair 24: NC (=O) -> NC(=O) (frequency 590315)
# pair 25: c (C) -> c(C) (frequency 577867)
# pair 26: (C) C -> (C)C (frequency 563880)
# pair 27: F ) -> F) (frequency 539799)
# pair 28: c1cc cc -> c1cccc (frequency 532053)
# pair 29: CC 1 -> CC1 (frequency 506017)
# pair 30: )cc 1 -> )cc1 (frequency 502946)
# pair 31: ) =O) -> )=O) (frequency 443461)
# pair 32: c2cc cc -> c2cccc (frequency 438521)
# pair 33: c1 n -> c1n (frequency 423857)
# pair 34: c1cc c( -> c1ccc( (frequency 409447)
# pair 35: C 1 -> C1 (frequency 387157)
# pair 36: ( CC -> (CC (frequency 386408)
# pair 37: ) n -> )n (frequency 373487)
# pair 38: N (C -> N(C (frequency 365374)
# pair 39: cc cc -> cccc (frequency 359578)
# pair 40: 2 CC -> 2CC (frequency 359107)
# pair 41: O CC -> OCC (frequency 340224)
# pair 42: ( F) -> (F) (frequency 321750)
# pair 43: c2 n -> c2n (frequency 320021)
# pair 44: ) c1 -> )c1 (frequency 310879)
# pair 45: O = -> O= (frequency 306244)
# pair 46: c2cccc c2 -> c2ccccc2 (frequency 291224)
# pair 47: cc 1 -> cc1 (frequency 285146)
# pair 48: 1 CC -> 1CC (frequency 279353)
# pair 49: c1cccc c1 -> c1ccccc1 (frequency 264965)
# pair 50: n 2 -> n2 (frequency 258462)
# pair 51: ( NC -> (NC (frequency 249272)
# pair 52: S (=O) -> S(=O) (frequency 248238)
# pair 53: ) CC -> )CC (frequency 247199)
# pair 54: O= C -> O=C (frequency 241374)
# pair 55: c( - -> c(- (frequency 240575)
# pair 56: C O -> CO (frequency 237448)
# pair 57: F )cc -> F)cc (frequency 219760)
# pair 58: c2 c( -> c2c( (frequency 219472)
# pair 59: c (=O) -> c(=O) (frequency 205646)
# pair 60: (=O) NC -> (=O)NC (frequency 197455)
# pair 61: NC(=O) C -> NC(=O)C (frequency 188344)
# pair 62: ( - -> (- (frequency 184847)
# pair 63: # N -> #N (frequency 184579)
# pair 64: (=O) C -> (=O)C (frequency 183944)
# pair 65: c2cc c( -> c2ccc( (frequency 180391)
# pair 66: c1 C -> c1C (frequency 176242)
# pair 67: c s -> cs (frequency 171723)
# pair 68: c3 cc -> c3cc (frequency 171299)
# pair 69: ( OC -> (OC (frequency 167545)
# pair 70: c3 cccc -> c3cccc (frequency 164113)
# pair 71: c1cc c(C -> c1ccc(C (frequency 156436)
# pair 72: c1 c( -> c1c( (frequency 152973)
# pair 73: ) c2 -> )c2 (frequency 150764)
# pair 74: 2) =O) -> 2)=O) (frequency 149084)
# pair 75: ) =O -> )=O (frequency 147231)
# pair 76: n n -> nn (frequency 146804)
# pair 77: N ( -> N( (frequency 142002)
# pair 78: ( O -> (O (frequency 141543)
# pair 79: 2 C -> 2C (frequency 137964)
# pair 80: (C (=O)N -> (C(=O)N (frequency 135754)
# pair 81: 2) c1 -> 2)c1 (frequency 133364)
# pair 82: ) c( -> )c( (frequency 133025)
# pair 83: ) N -> )N (frequency 132133)
# pair 84: 2 )cc1 -> 2)cc1 (frequency 130104)
# pair 85: c3cccc c3 -> c3ccccc3 (frequency 122715)
# pair 86: o 1 -> o1 (frequency 118047)
# pair 87: CC (=O)N -> CC(=O)N (frequency 116327)
# pair 88: 1 C -> 1C (frequency 114663)
# pair 89: Cl )cc -> Cl)cc (frequency 114466)
# pair 90: c( N -> c(N (frequency 113286)
# pair 91: 3 CC -> 3CC (frequency 110145)
# pair 92: n cc -> ncc (frequency 109642)
# pair 93: C c1cc -> Cc1cc (frequency 107789)
# pair 94: c(C) cc -> c(C)cc (frequency 104876)
# pair 95: CC (C) -> CC(C) (frequency 103021)
# pair 96: (F) (F) -> (F)(F) (frequency 102657)
# pair 97: N(C (=O) -> N(C(=O) (frequency 100349)
# pair 98: 3 ) -> 3) (frequency 100106)
# pair 99: c1 cn -> c1cn (frequency 98848)
# pair 100: s 1 -> s1 (frequency 96612)
# pair 101: CCC 1 -> CCC1 (frequency 96080)
# pair 102: 2) n -> 2)n (frequency 95802)
# pair 103: c n1 -> cn1 (frequency 94941)
# pair 104: c(C) n -> c(C)n (frequency 94251)
# pair 105: C c1n -> Cc1n (frequency 93676)
# pair 106: c 4 -> c4 (frequency 93025)
# pair 107: 2 )cc -> 2)cc (frequency 92239)
# pair 108: NC (=O)N -> NC(=O)N (frequency 89185)
# pair 109: c1 2 -> c12 (frequency 89168)
# pair 110: S(=O) (=O) -> S(=O)(=O) (frequency 86116)
# pair 111: CC N -> CCN (frequency 86085)
# pair 112: c2 ) -> c2) (frequency 85986)
# pair 113: 2 CCC -> 2CCC (frequency 85095)
# pair 114: F )cc1 -> F)cc1 (frequency 84697)
# pair 115: c3 c( -> c3c( (frequency 83611)
# pair 116: )C 1 -> )C1 (frequency 82966)
# pair 117: n 3 -> n3 (frequency 82858)
# pair 118: cc c1 -> ccc1 (frequency 82694)
# pair 119: OC (=O) -> OC(=O) (frequency 82663)
# pair 120: CC O -> CCO (frequency 82168)
# pair 121: ( NC(=O) -> (NC(=O) (frequency 81671)
# pair 122: O=C (N -> O=C(N (frequency 81387)
# pair 123: c(C (=O)N -> c(C(=O)N (frequency 80496)
# pair 124: (C (N -> (C(N (frequency 80386)
# pair 125: (C) (C)C -> (C)(C)C (frequency 79684)
# pair 126: n (C) -> n(C) (frequency 75905)
# pair 127: 3 )n -> 3)n (frequency 75838)
# pair 128: OC )cc -> OC)cc (frequency 73760)
# pair 129: c1cc ( -> c1cc( (frequency 73187)
# pair 130: c2 cn -> c2cn (frequency 73102)
# pair 131: c1 ) -> c1) (frequency 73007)
# pair 132: 2) CC1 -> 2)CC1 (frequency 69721)
# pair 133: 2) n1 -> 2)n1 (frequency 67581)
# pair 134: 1 CCC -> 1CCC (frequency 67555)
# pair 135: C1 C -> C1C (frequency 67460)
# pair 136: 2CC CC -> 2CCCC (frequency 65367)
# pair 137: ) n1 -> )n1 (frequency 63845)
# pair 138: N (CC -> N(CC (frequency 63397)
# pair 139: ( CCC -> (CCC (frequency 62977)
# pair 140: (=O) =O) -> (=O)=O) (frequency 62907)
# pair 141: S(=O) (=O)N -> S(=O)(=O)N (frequency 62150)
# pair 142: n1 cc -> n1cc (frequency 61911)
# pair 143: c1n n -> c1nn (frequency 61792)
# pair 144: ( Cl -> (Cl (frequency 60940)
# pair 145: c2 C -> c2C (frequency 60416)
# pair 146: c1ccc( - -> c1ccc(- (frequency 60336)
# pair 147: N 1CC -> N1CC (frequency 60321)
# pair 148: 2) C -> 2)C (frequency 60196)
# pair 149: (C) n -> (C)n (frequency 59898)
# pair 150: NC ( -> NC( (frequency 58949)
# pair 151: (C) =O) -> (C)=O) (frequency 58213)
# pair 152: c1 c(C -> c1c(C (frequency 58116)
# pair 153: c3 n -> c3n (frequency 58041)
# pair 154: (C #N -> (C#N (frequency 58013)
# pair 155: [nH] 1 -> [nH]1 (frequency 57154)
# pair 156: N (C)C -> N(C)C (frequency 57049)
# pair 157: O=C (C -> O=C(C (frequency 56965)
# pair 158: )=O) C -> )=O)C (frequency 56670)
# pair 159: ) CC1 -> )CC1 (frequency 56503)
# pair 160: c( S -> c(S (frequency 56119)
# pair 161: )cc c1 -> )ccc1 (frequency 55890)
# pair 162: C ( -> C( (frequency 53950)
# pair 163: CC CC -> CCCC (frequency 53939)
# pair 164: cs 1 -> cs1 (frequency 53632)
# pair 165: )=O) cc -> )=O)cc (frequency 52381)
# pair 166: 2) C1 -> 2)C1 (frequency 52286)
# pair 167: ( OCC -> (OCC (frequency 51129)
# pair 168: c o -> co (frequency 51093)
# pair 169: c(C) c1 -> c(C)c1 (frequency 50862)
# pair 170: (C) cc -> (C)cc (frequency 50195)
# pair 171: c2 s -> c2s (frequency 49766)
# pair 172: (F)(F) F) -> (F)(F)F) (frequency 49659)
# pair 173: c1ccc( F)cc1 -> c1ccc(F)cc1 (frequency 49342)
# pair 174: c1cc c2c( -> c1ccc2c( (frequency 49283)
# pair 175: N(C (=O)C -> N(C(=O)C (frequency 49276)
# pair 176: c1cc 2 -> c1cc2 (frequency 48956)
# pair 177: c1cc (C -> c1cc(C (frequency 48779)
# pair 178: )C (=O) -> )C(=O) (frequency 48548)
# pair 179: C1 CC -> C1CC (frequency 48508)
# pair 180: c( CC -> c(CC (frequency 48181)
# pair 181: c( F) -> c(F) (frequency 48179)
# pair 182: c2ccc( F)cc -> c2ccc(F)cc (frequency 47956)
# pair 183: o n -> on (frequency 47772)
# pair 184: c1 s -> c1s (frequency 47508)
# pair 185: 3 )cc -> 3)cc (frequency 47499)
# pair 186: = C -> =C (frequency 46962)
# pair 187: c1cc n -> c1ccn (frequency 46839)
# pair 188: N 1 -> N1 (frequency 46242)
# pair 189: NC (C -> NC(C (frequency 45546)
# pair 190: c1 (C -> c1(C (frequency 45530)
# pair 191: (=O) OC -> (=O)OC (frequency 45349)
# pair 192: cn c2 -> cnc2 (frequency 44323)
# pair 193: c [nH] -> c[nH] (frequency 44148)
# pair 194: c2n n -> c2nn (frequency 44137)
# pair 195: O CC1 -> OCC1 (frequency 43925)
# pair 196: c2n cc -> c2ncc (frequency 43310)
# pair 197: N 2CC -> N2CC (frequency 43155)
# pair 198: C (C -> C(C (frequency 43040)
# pair 199: ( F)cc -> (F)cc (frequency 42753)
# pair 200: CC (C)C -> CC(C)C (frequency 42664)
# pair 201: c1ccc( Cl -> c1ccc(Cl (frequency 42347)
# pair 202: c1n cc -> c1ncc (frequency 41896)
# pair 203: c(C (N -> c(C(N (frequency 41047)
# pair 204: c(- c2cc -> c(-c2cc (frequency 41038)
# pair 205: C (N -> C(N (frequency 40476)
# pair 206: c(C #N -> c(C#N (frequency 40409)
# pair 207: cn c1 -> cnc1 (frequency 40342)
# pair 208: CCC (=O)N -> CCC(=O)N (frequency 40288)
# pair 209: c(C) cc1 -> c(C)cc1 (frequency 40203)
# pair 210: c( OC -> c(OC (frequency 40172)
# pair 211: 3 )CC -> 3)CC (frequency 39870)
# pair 212: CCC O -> CCCO (frequency 39474)
# pair 213: O=C ( -> O=C( (frequency 39347)
# pair 214: c1ccc( OC -> c1ccc(OC (frequency 38858)
# pair 215: ( NC(=O)C -> (NC(=O)C (frequency 38616)
# pair 216: (C) CC -> (C)CC (frequency 38477)
# pair 217: c1cccc (C -> c1cccc(C (frequency 38435)
# pair 218: c2 c1 -> c2c1 (frequency 38287)
# pair 219: (C)C ) -> (C)C) (frequency 37650)
# pair 220: n2 cc -> n2cc (frequency 37180)
# pair 221: c1ccccc1 C -> c1ccccc1C (frequency 37157)
# pair 222: N 1C -> N1C (frequency 36916)
# pair 223: c(=O) [nH] -> c(=O)[nH] (frequency 36724)
# pair 224: C c1ccc( -> Cc1ccc( (frequency 36525)
# pair 225: )N 1CC -> )N1CC (frequency 36475)
# pair 226: N # -> N# (frequency 36191)
# pair 227: n c1 -> nc1 (frequency 36150)
# pair 228: cccc 1 -> cccc1 (frequency 35820)
# pair 229: n1 n -> n1n (frequency 35519)
# pair 230: C OC(=O) -> COC(=O) (frequency 35388)
# pair 231: C OC -> COC (frequency 35365)
# pair 232: C OCC -> COCC (frequency 35352)
# pair 233: c3cc c( -> c3ccc( (frequency 34962)
# pair 234: NC(=O) NC -> NC(=O)NC (frequency 34905)
# pair 235: 3 )C -> 3)C (frequency 34255)
# pair 236: (C O -> (CO (frequency 34126)
# pair 237: )=O) CC -> )=O)CC (frequency 33992)
# pair 238: (O )C -> (O)C (frequency 33956)
# pair 239: c1ccc(C (=O)N -> c1ccc(C(=O)N (frequency 33353)
# pair 240: O=C (NC -> O=C(NC (frequency 33201)
# pair 241: (O ) -> (O) (frequency 33195)
# pair 242: c1cccc 2 -> c1cccc2 (frequency 32822)
# pair 243: c2ccccc2 1 -> c2ccccc21 (frequency 32599)
# pair 244: ( Br -> (Br (frequency 32595)
# pair 245: NC(=O) c2cc -> NC(=O)c2cc (frequency 32494)
# pair 246: ( c2cc -> (c2cc (frequency 32490)
# pair 247: 3 C -> 3C (frequency 32333)
# pair 248: cc 2 -> cc2 (frequency 31967)
# pair 249: CC OC -> CCOC (frequency 31693)
# pair 250: c1 cs -> c1cs (frequency 31387)
# pair 251: (=O)N 1CC -> (=O)N1CC (frequency 31209)
# pair 252: O 2 -> O2 (frequency 30911)
# pair 253: c1ccc(Cl )cc1 -> c1ccc(Cl)cc1 (frequency 30720)
# pair 254: )=O) cc1 -> )=O)cc1 (frequency 30587)
# pair 255: c1 c(C) -> c1c(C) (frequency 30543)
# pair 256: n (CC -> n(CC (frequency 30300)
# pair 257: CC 2 -> CC2 (frequency 30216)
# pair 258: CC (N -> CC(N (frequency 29814)
# pair 259: CC1 C -> CC1C (frequency 28989)
# pair 260: ( Cl)cc -> (Cl)cc (frequency 28862)
# pair 261: CCC 2 -> CCC2 (frequency 28837)
# pair 262: NC (N -> NC(N (frequency 28715)
# pair 263: n c2 -> nc2 (frequency 28620)
# pair 264: c2ccccc2 ) -> c2ccccc2) (frequency 28496)
# pair 265: cc c2 -> ccc2 (frequency 28327)
# pair 266: CO c1ccc( -> COc1ccc( (frequency 28146)
# pair 267: c1cc (- -> c1cc(- (frequency 27982)
# pair 268: )c( OC -> )c(OC (frequency 27973)
# pair 269: C (=O) -> C(=O) (frequency 27855)
# pair 270: c1cc2 c( -> c1cc2c( (frequency 27827)
# pair 271: c1ccc2c( c1) -> c1ccc2c(c1) (frequency 27600)
# pair 272: n1 C -> n1C (frequency 27455)
# pair 273: 3 )c2 -> 3)c2 (frequency 27402)
# pair 274: ( S -> (S (frequency 27367)
# pair 275: c(- c3cc -> c(-c3cc (frequency 27306)
# pair 276: O 1 -> O1 (frequency 27155)
# pair 277: (C)C )n -> (C)C)n (frequency 27151)
# pair 278: c( Cl -> c(Cl (frequency 26949)
# pair 279: )cc c2 -> )ccc2 (frequency 26810)
# pair 280: ) cn -> )cn (frequency 26767)
# pair 281: n1 cn -> n1cn (frequency 26701)
# pair 282: c1 =O -> c1=O (frequency 26611)
# pair 283: )cc 2 -> )cc2 (frequency 26592)
# pair 284: (C (=O)NC -> (C(=O)NC (frequency 26473)
# pair 285: 3 )=O) -> 3)=O) (frequency 26341)
# pair 286: (=O) OCC -> (=O)OCC (frequency 26214)
# pair 287: )C (=O)N -> )C(=O)N (frequency 26193)
# pair 288: N(C ( -> N(C( (frequency 26096)
# pair 289: c1cc c -> c1ccc (frequency 25996)
# pair 290: N (C) -> N(C) (frequency 25754)
# pair 291: CO c1cc -> COc1cc (frequency 25625)
# pair 292: c( NC -> c(NC (frequency 25370)
# pair 293: 2CC CCC -> 2CCCCC (frequency 25296)
# pair 294: 2 =O) -> 2=O) (frequency 25208)
# pair 295: c2 o -> c2o (frequency 24863)
# pair 296: S (C) -> S(C) (frequency 24833)
# pair 297: c1ccn cc1 -> c1ccncc1 (frequency 24772)
# pair 298: n2 C -> n2C (frequency 24717)
# pair 299: n2 cn -> n2cn (frequency 24707)
# pair 300: (NC (=O)N -> (NC(=O)N (frequency 24686)
# pair 301: C c1cccc -> Cc1cccc (frequency 24478)
# pair 302: c2ccc( Cl)cc -> c2ccc(Cl)cc (frequency 24362)
# pair 303: c1 o -> c1o (frequency 24231)
# pair 304: c1cc cs1 -> c1cccs1 (frequency 24077)
# pair 305: 2)cc c1 -> 2)ccc1 (frequency 24062)
# pair 306: c1c( F)cc -> c1c(F)cc (frequency 23883)
# pair 307: = CC -> =CC (frequency 23854)
# pair 308: )=O) c1 -> )=O)c1 (frequency 23804)
# pair 309: NC(=O) CC -> NC(=O)CC (frequency 23683)
# pair 310: )c1 C -> )c1C (frequency 23648)
# pair 311: c2 [nH] -> c2[nH] (frequency 23495)
# pair 312: s c1 -> sc1 (frequency 23353)
# pair 313: N S(=O)(=O) -> NS(=O)(=O) (frequency 23322)
# pair 314: c2 c(C) -> c2c(C) (frequency 23091)
# pair 315: n2 )cc1 -> n2)cc1 (frequency 23014)
# pair 316: (CC ) -> (CC) (frequency 22857)
# pair 317: c1cc cnc1 -> c1cccnc1 (frequency 22849)
# pair 318: CC1 ) -> CC1) (frequency 22838)
# pair 319: c2 =O) -> c2=O) (frequency 22786)
# pair 320: n (- -> n(- (frequency 22683)
# pair 321: (F)(F) F -> (F)(F)F (frequency 22648)
# pair 322: cn c3 -> cnc3 (frequency 22603)
# pair 323: c1ccc o1 -> c1ccco1 (frequency 22489)
# pair 324: CC (=O) -> CC(=O) (frequency 22436)
# pair 325: 2CC OCC -> 2CCOCC (frequency 22344)
# pair 326: CC (=O)NC -> CC(=O)NC (frequency 22255)
# pair 327: c1 (- -> c1(- (frequency 22251)
# pair 328: CO c1ccc(C -> COc1ccc(C (frequency 22190)
# pair 329: N 2C -> N2C (frequency 22159)
# pair 330: ) c3 -> )c3 (frequency 21686)
# pair 331: (F) c1 -> (F)c1 (frequency 21680)
# pair 332: c(F) c1 -> c(F)c1 (frequency 21648)
# pair 333: N(C (C -> N(C(C (frequency 21623)
# pair 334: ) CCC -> )CCC (frequency 21601)
# pair 335: c1 [nH] -> c1[nH] (frequency 21236)
# pair 336: (CC (=O)N -> (CC(=O)N (frequency 21219)
# pair 337: c3 cn -> c3cn (frequency 21146)
# pair 338: c1 c2c( -> c1c2c( (frequency 21022)
# pair 339: C1 CCC -> C1CCC (frequency 21022)
# pair 340: n 2) -> n2) (frequency 21002)
# pair 341: c1cccc n1 -> c1ccccn1 (frequency 20877)
# pair 342: c1cc( F)cc -> c1cc(F)cc (frequency 20833)
# pair 343: CC OC(=O) -> CCOC(=O) (frequency 20759)
# pair 344: ) NC -> )NC (frequency 20732)
# pair 345: (NC (C -> (NC(C (frequency 20721)
# pair 346: S(=O) (N -> S(=O)(N (frequency 20589)
# pair 347: CC(C) (C) -> CC(C)(C) (frequency 20589)
# pair 348: 3CC CC -> 3CCCC (frequency 20584)
# pair 349: c(C (=O)NC -> c(C(=O)NC (frequency 20570)
# pair 350: (C) c1 -> (C)c1 (frequency 20491)
# pair 351: C c1ccc(C -> Cc1ccc(C (frequency 20433)
# pair 352: C n1 -> Cn1 (frequency 20292)
# pair 353: ) (=O)=O) -> )(=O)=O) (frequency 20285)
# pair 354: S (N -> S(N (frequency 20261)
# pair 355: S c1n -> Sc1n (frequency 20250)
# pair 356: (NC ( -> (NC( (frequency 20150)
# pair 357: 3 c( -> 3c( (frequency 20081)
# pair 358: N(C)C (=O) -> N(C)C(=O) (frequency 20034)
# pair 359: O )cc -> O)cc (frequency 19993)
# pair 360: c( NC(=O) -> c(NC(=O) (frequency 19885)
# pair 361: (Cl )c1 -> (Cl)c1 (frequency 19867)
# pair 362: C1 CC1 -> C1CC1 (frequency 19832)
# pair 363: ) o -> )o (frequency 19814)
# pair 364: c(S C -> c(SC (frequency 19781)
# pair 365: CC1 CC -> CC1CC (frequency 19714)
# pair 366: n2 n -> n2n (frequency 19701)
# pair 367: c1cc (OC -> c1cc(OC (frequency 19589)
# pair 368: cc1 C -> cc1C (frequency 19545)
# pair 369: S ( -> S( (frequency 19488)
# pair 370: CC ( -> CC( (frequency 19413)
# pair 371: N(C (=O)N -> N(C(=O)N (frequency 19260)
# pair 372: c( NC(=O)C -> c(NC(=O)C (frequency 19247)
# pair 373: 2) s1 -> 2)s1 (frequency 19216)
# pair 374: c2cc c3c( -> c2ccc3c( (frequency 19070)
# pair 375: c4 cccc -> c4cccc (frequency 18981)
# pair 376: c2ccccc2 )n -> c2ccccc2)n (frequency 18953)
# pair 377: n (C -> n(C (frequency 18853)
# pair 378: )C (=O)C -> )C(=O)C (frequency 18840)
# pair 379: N CC -> NCC (frequency 18832)
# pair 380: c1ccc( F) -> c1ccc(F) (frequency 18753)
# pair 381: o c(C -> oc(C (frequency 18729)
# pair 382: c1cc (C) -> c1cc(C) (frequency 18694)
# pair 383: ) s -> )s (frequency 18584)
# pair 384: OC O -> OCO (frequency 18530)
# pair 385: c2 cs -> c2cs (frequency 18270)
# pair 386: 2) CC -> 2)CC (frequency 18262)
# pair 387: CC NC(=O) -> CCNC(=O) (frequency 18142)
# pair 388: )cc cc -> )cccc (frequency 18126)
# pair 389: c12 c( -> c12c( (frequency 18078)
# pair 390: c(=O) n(C) -> c(=O)n(C) (frequency 18073)
# pair 391: c2cc c(C -> c2ccc(C (frequency 17826)
# pair 392: S(C) (=O)=O) -> S(C)(=O)=O) (frequency 17738)
# pair 393: OC (C)C -> OC(C)C (frequency 17673)
# pair 394: ) c1ccccc1 -> )c1ccccc1 (frequency 17670)
# pair 395: OCC O -> OCCO (frequency 17629)
# pair 396: c2 n1 -> c2n1 (frequency 17593)
# pair 397: 1CC CC1 -> 1CCCC1 (frequency 17593)
# pair 398: c2c( F)cc -> c2c(F)cc (frequency 17497)
# pair 399: S(=O) ( -> S(=O)( (frequency 17351)
# pair 400: CC c1n -> CCc1n (frequency 17330)
# pair 401: c(C) n1 -> c(C)n1 (frequency 17278)
# pair 402: (=O) =O -> (=O)=O (frequency 17215)
# pair 403: c3ccc( F)cc -> c3ccc(F)cc (frequency 17123)
# pair 404: 2)=O) cc -> 2)=O)cc (frequency 17085)
# pair 405: OCC (=O)N -> OCC(=O)N (frequency 17076)
# pair 406: Cl ) -> Cl) (frequency 17026)
# pair 407: CC (C -> CC(C (frequency 16890)
# pair 408: c1 (C) -> c1(C) (frequency 16884)
# pair 409: c1cc2c( cc1 -> c1cc2c(cc1 (frequency 16872)
# pair 410: (C) (C) -> (C)(C) (frequency 16859)
# pair 411: 2)n c1 -> 2)nc1 (frequency 16817)
# pair 412: O ) -> O) (frequency 16816)
# pair 413: S C -> SC (frequency 16807)
# pair 414: S(=O) (=O)NC -> S(=O)(=O)NC (frequency 16774)
# pair 415: 1 CC1 -> 1CC1 (frequency 16701)
# pair 416: 3 )cc1 -> 3)cc1 (frequency 16678)
# pair 417: o n1 -> on1 (frequency 16615)
# pair 418: c1 c(- -> c1c(- (frequency 16605)
# pair 419: 2) cn1 -> 2)cn1 (frequency 16566)
# pair 420: c2ccccc2 C -> c2ccccc2C (frequency 16490)
# pair 421: c(C) c2 -> c(C)c2 (frequency 16481)
# pair 422: c2cc ncc -> c2ccncc (frequency 16468)
# pair 423: c1ccc2c( c1 -> c1ccc2c(c1 (frequency 16422)
# pair 424: 3 )c1 -> 3)c1 (frequency 16271)
# pair 425: )cc cc1 -> )cccc1 (frequency 16265)
# pair 426: )C 2 -> )C2 (frequency 16263)
# pair 427: S(=O) (=O)C -> S(=O)(=O)C (frequency 16249)
# pair 428: CO c1cccc -> COc1cccc (frequency 16222)
# pair 429: CCN (CC -> CCN(CC (frequency 16121)
# pair 430: (F)(F) F)cc -> (F)(F)F)cc (frequency 16080)
# pair 431: c3ccccc3 )n -> c3ccccc3)n (frequency 15846)
# pair 432: c1C (=O)N -> c1C(=O)N (frequency 15819)
# pair 433: cc c3 -> ccc3 (frequency 15801)
# pair 434: O CCC -> OCCC (frequency 15741)
# pair 435: cc (C -> cc(C (frequency 15726)
# pair 436: 3 CCC -> 3CCC (frequency 15706)
# pair 437: c1c( Cl)cc -> c1c(Cl)cc (frequency 15690)
# pair 438: c2cc cnc2 -> c2cccnc2 (frequency 15639)
# pair 439: c2 1 -> c21 (frequency 15589)
# pair 440: c2n c(C -> c2nc(C (frequency 15570)
# pair 441: 2CC 2) -> 2CC2) (frequency 15478)
# pair 442: (C)C (=O)N -> (C)C(=O)N (frequency 15468)
# pair 443: C n1cc -> Cn1cc (frequency 15384)
# pair 444: c1cc (N -> c1cc(N (frequency 15380)
# pair 445: c3 s -> c3s (frequency 15354)
# pair 446: c1cc c(C)cc1 -> c1ccc(C)cc1 (frequency 15328)
# pair 447: c( F)cc -> c(F)cc (frequency 15287)
# pair 448: c2cccc (F) -> c2cccc(F) (frequency 15257)
# pair 449: c2c( cccc -> c2c(cccc (frequency 15222)
# pair 450: (OC )cc -> (OC)cc (frequency 15218)
# pair 451: (F) F) -> (F)F) (frequency 15195)
# pair 452: 2)=O) cc1 -> 2)=O)cc1 (frequency 15181)
# pair 453: c4cccc c4 -> c4ccccc4 (frequency 15160)
# pair 454: c1 c(C)cc -> c1c(C)cc (frequency 15084)
# pair 455: 1CC CCC1 -> 1CCCCC1 (frequency 15071)
# pair 456: (CC (N -> (CC(N (frequency 15059)
# pair 457: 2 c( -> 2c( (frequency 15057)
# pair 458: 2)=O) c1 -> 2)=O)c1 (frequency 15055)
# pair 459: (CC )CC -> (CC)CC (frequency 15052)
# pair 460: C N(C -> CN(C (frequency 15040)
# pair 461: c3 ncc -> c3ncc (frequency 14992)
# pair 462: c(C)n o -> c(C)no (frequency 14991)
# pair 463: n1 - -> n1- (frequency 14929)
# pair 464: )c( N -> )c(N (frequency 14904)
# pair 465: CO c1ccccc1 -> COc1ccccc1 (frequency 14809)
# pair 466: )c( Cl -> )c(Cl (frequency 14793)
# pair 467: c2cc c(C)cc -> c2ccc(C)cc (frequency 14790)
# pair 468: c2 )cc1 -> c2)cc1 (frequency 14775)
# pair 469: c1cc( Cl)cc -> c1cc(Cl)cc (frequency 14768)
# pair 470: (C)C )C -> (C)C)C (frequency 14716)
# pair 471: (C) n1 -> (C)n1 (frequency 14612)
# pair 472: c2 )c1 -> c2)c1 (frequency 14584)
# pair 473: c(C) s -> c(C)s (frequency 14563)
# pair 474: [nH] c(=O) -> [nH]c(=O) (frequency 14490)
# pair 475: c1n c(C -> c1nc(C (frequency 14456)
# pair 476: c1 (N -> c1(N (frequency 14428)
# pair 477: c(N )n -> c(N)n (frequency 14418)
# pair 478: ) c(C -> )c(C (frequency 14361)
# pair 479: c2ccc( OC)cc -> c2ccc(OC)cc (frequency 14292)
# pair 480: (CC )C -> (CC)C (frequency 14248)
# pair 481: (OC )c1 -> (OC)c1 (frequency 14247)
# pair 482: # C -> #C (frequency 14230)
# pair 483: c2cc cs -> c2cccs (frequency 14225)
# pair 484: c2cc co -> c2ccco (frequency 14197)
# pair 485: cc 2) -> cc2) (frequency 14106)
# pair 486: c2n cn -> c2ncn (frequency 14097)
# pair 487: CCN 1C -> CCN1C (frequency 14023)
# pair 488: c2cc (F)cc -> c2cc(F)cc (frequency 14013)
# pair 489: c1ccccc1 ) -> c1ccccc1) (frequency 13991)
# pair 490: c1 =O) -> c1=O) (frequency 13987)
# pair 491: O=C (CC -> O=C(CC (frequency 13971)
# pair 492: c1cccc (F)c1 -> c1cccc(F)c1 (frequency 13884)
# pair 493: N1 (C -> N1(C (frequency 13878)
# pair 494: c1c( OC)cc -> c1c(OC)cc (frequency 13860)
# pair 495: OC 1 -> OC1 (frequency 13793)
# pair 496: c4 cc -> c4cc (frequency 13747)
# pair 497: 3CC OCC -> 3CCOCC (frequency 13733)
# pair 498: c2n cccc -> c2ncccc (frequency 13729)
# pair 499: c2c( cc -> c2c(cc (frequency 13713)
# pair 500: c2 )=O) -> c2)=O) (frequency 13696)
# pair 501: c2s cc -> c2scc (frequency 13647)
# pair 502: )cc1 C -> )cc1C (frequency 13645)
# pair 503: N1C (=O) -> N1C(=O) (frequency 13598)
# pair 504: 2CC N( -> 2CCN( (frequency 13590)
# pair 505: 4 )n -> 4)n (frequency 13534)
# pair 506: 2)n o1 -> 2)no1 (frequency 13529)
# pair 507: ) c(=O) -> )c(=O) (frequency 13511)
# pair 508: cccc 1C -> cccc1C (frequency 13484)
# pair 509: (Cl )c2 -> (Cl)c2 (frequency 13426)
# pair 510: c3 C -> c3C (frequency 13392)
# pair 511: c1cccc (- -> c1cccc(- (frequency 13259)
# pair 512: c2ccccc2 )c1 -> c2ccccc2)c1 (frequency 13202)
# pair 513: 2) o1 -> 2)o1 (frequency 13178)
# pair 514: c(C) c1C -> c(C)c1C (frequency 13158)
# pair 515: CC n1 -> CCn1 (frequency 13082)
# pair 516: c1 c(C(=O)N -> c1c(C(=O)N (frequency 13081)
# pair 517: )n c1 -> )nc1 (frequency 13073)
# pair 518: (NC (N -> (NC(N (frequency 12997)
# pair 519: c2ccc3c( c2) -> c2ccc3c(c2) (frequency 12964)
# pair 520: ) cn1 -> )cn1 (frequency 12961)
# pair 521: c2) CC1 -> c2)CC1 (frequency 12954)
# pair 522: n n1 -> nn1 (frequency 12907)
# pair 523: C (C) -> C(C) (frequency 12860)
# pair 524: c1cccc (Cl)c1 -> c1cccc(Cl)c1 (frequency 12822)
# pair 525: 1CC N( -> 1CCN( (frequency 12816)
# pair 526: )C ( -> )C( (frequency 12810)
# pair 527: c1cc (C(=O)N -> c1cc(C(=O)N (frequency 12804)
# pair 528: c3 nn -> c3nn (frequency 12749)
# pair 529: S c1nn -> Sc1nn (frequency 12746)
# pair 530: c(- n3 -> c(-n3 (frequency 12717)
# pair 531: (C)C )cc -> (C)C)cc (frequency 12629)
# pair 532: (OC )=O) -> (OC)=O) (frequency 12600)
# pair 533: n2 nn -> n2nn (frequency 12574)
# pair 534: #N )cc1 -> #N)cc1 (frequency 12516)
# pair 535: c2ccccc2 F) -> c2ccccc2F) (frequency 12514)
# pair 536: c1ccc(OC )cc1 -> c1ccc(OC)cc1 (frequency 12481)
# pair 537: (C(N )=O) -> (C(N)=O) (frequency 12446)
# pair 538: c(C O -> c(CO (frequency 12432)
# pair 539: c2cc (C -> c2cc(C (frequency 12376)
# pair 540: (C)C )c1 -> (C)C)c1 (frequency 12376)
# pair 541: c1cc c(C) -> c1ccc(C) (frequency 12359)
# pair 542: c1c( N -> c1c(N (frequency 12351)
# pair 543: c1ccc( N -> c1ccc(N (frequency 12258)
# pair 544: (C)C )cc1 -> (C)C)cc1 (frequency 12246)
# pair 545: cn 2 -> cn2 (frequency 12238)
# pair 546: C =CC -> C=CC (frequency 12237)
# pair 547: c1 - -> c1- (frequency 11997)
# pair 548: N( CCC -> N(CCC (frequency 11969)
# pair 549: (O )CC -> (O)CC (frequency 11946)
# pair 550: c2cccc c12 -> c2ccccc12 (frequency 11943)
# pair 551: c(Cl )c1 -> c(Cl)c1 (frequency 11910)
# pair 552: COC (=O)C -> COC(=O)C (frequency 11907)
# pair 553: c1ccc( O -> c1ccc(O (frequency 11854)
# pair 554: c1 c[nH] -> c1c[nH] (frequency 11839)
# pair 555: (C)C )=O) -> (C)C)=O) (frequency 11816)
# pair 556: 2CCC O -> 2CCCO (frequency 11794)
# pair 557: c2) n1 -> c2)n1 (frequency 11745)
# pair 558: )C1 CC1 -> )C1CC1 (frequency 11707)
# pair 559: c2ccc(F)cc 2 -> c2ccc(F)cc2 (frequency 11611)
# pair 560: Br )cc -> Br)cc (frequency 11599)
# pair 561: 2) c1C -> 2)c1C (frequency 11506)
# pair 562: Cc1n o -> Cc1no (frequency 11500)
# pair 563: c2ccccc2 )n1 -> c2ccccc2)n1 (frequency 11489)
# pair 564: CCCO 1 -> CCCO1 (frequency 11488)
# pair 565: C NC(=O) -> CNC(=O) (frequency 11485)
# pair 566: C c1ccccc1 -> Cc1ccccc1 (frequency 11464)
# pair 567: (C) O -> (C)O (frequency 11441)
# pair 568: c(C N -> c(CN (frequency 11434)
# pair 569: (C#N ) -> (C#N) (frequency 11403)
# pair 570: Br )cc1 -> Br)cc1 (frequency 11378)
# pair 571: c( OCC -> c(OCC (frequency 11350)
# pair 572: (N CC -> (NCC (frequency 11330)
# pair 573: c4 c( -> c4c( (frequency 11324)
# pair 574: n2cc cn -> n2cccn (frequency 11234)
# pair 575: c2n ( -> c2n( (frequency 11227)
# pair 576: c(OC )c1 -> c(OC)c1 (frequency 11222)
# pair 577: OC (C)(C)C -> OC(C)(C)C (frequency 11217)
# pair 578: OC ) -> OC) (frequency 11215)
# pair 579: OC O2 -> OCO2 (frequency 11196)
# pair 580: n2 ncc -> n2ncc (frequency 11193)
# pair 581: 1CC OCC1 -> 1CCOCC1 (frequency 11183)
# pair 582: c1 c(C)n -> c1c(C)n (frequency 11155)
# pair 583: C # -> C# (frequency 11132)
# pair 584: (C(=O)N CC -> (C(=O)NCC (frequency 11126)
# pair 585: c1cc(F)cc c1 -> c1cc(F)ccc1 (frequency 11084)
# pair 586: c2cccc (Cl)c2 -> c2cccc(Cl)c2 (frequency 11031)
# pair 587: 3CC CCC -> 3CCCCC (frequency 11003)
# pair 588: n1 nn -> n1nn (frequency 10976)
# pair 589: )C (C)C -> )C(C)C (frequency 10956)
# pair 590: OC ( -> OC( (frequency 10942)
# pair 591: c3 )n -> c3)n (frequency 10937)
# pair 592: C c1cn -> Cc1cn (frequency 10896)
# pair 593: O ( -> O( (frequency 10853)
# pair 594: NC (C)=O) -> NC(C)=O) (frequency 10827)
# pair 595: 2CC N(C -> 2CCN(C (frequency 10810)
# pair 596: c1ccc(- c2n -> c1ccc(-c2n (frequency 10805)
# pair 597: 3) o -> 3)o (frequency 10759)
# pair 598: )CC 2 -> )CC2 (frequency 10755)
# pair 599: c2 )n -> c2)n (frequency 10752)
# pair 600: N c1n -> Nc1n (frequency 10752)
# pair 601: c2cccc n -> c2ccccn (frequency 10713)
# pair 602: S c2n -> Sc2n (frequency 10700)
# pair 603: c2ccc( F) -> c2ccc(F) (frequency 10642)
# pair 604: c3c( cccc -> c3c(cccc (frequency 10637)
# pair 605: c2ccc( N -> c2ccc(N (frequency 10626)
# pair 606: c(C#N )cc -> c(C#N)cc (frequency 10624)
# pair 607: [nH] n1 -> [nH]n1 (frequency 10588)
# pair 608: n c1C -> nc1C (frequency 10579)
# pair 609: )C (N -> )C(N (frequency 10517)
# pair 610: n1 2 -> n12 (frequency 10483)
# pair 611: OCC O2 -> OCCO2 (frequency 10453)
# pair 612: c1c(F)cc cc1 -> c1c(F)cccc1 (frequency 10427)
# pair 613: N2CC OCC -> N2CCOCC (frequency 10427)
# pair 614: c1ccc( NC(=O)C -> c1ccc(NC(=O)C (frequency 10381)
# pair 615: CC (NC(=O) -> CC(NC(=O) (frequency 10380)
# pair 616: c2ccccc2 )CC1 -> c2ccccc2)CC1 (frequency 10335)
# pair 617: 4 CC -> 4CC (frequency 10309)
# pair 618: c(=O) n(CC -> c(=O)n(CC (frequency 10217)
# pair 619: cc n -> ccn (frequency 10198)
# pair 620: (CC O -> (CCO (frequency 10185)
# pair 621: CC CC1 -> CCCC1 (frequency 10173)
# pair 622: N(C(=O) c2cc -> N(C(=O)c2cc (frequency 10172)
# pair 623: O=C(N CC -> O=C(NCC (frequency 10149)
# pair 624: c1 (C)cc -> c1(C)cc (frequency 10125)
# pair 625: c1n o -> c1no (frequency 10110)
# pair 626: )N 1CCC -> )N1CCC (frequency 10029)
# pair 627: (C N -> (CN (frequency 10025)
# pair 628: c(C) nn -> c(C)nn (frequency 10001)
# pair 629: c1cccc (N -> c1cccc(N (frequency 9940)
# pair 630: n2 )cc -> n2)cc (frequency 9859)
# pair 631: n c(C -> nc(C (frequency 9782)
# pair 632: cc cn -> cccn (frequency 9771)
# pair 633: c1 on -> c1on (frequency 9764)
# pair 634: c1 (C(N -> c1(C(N (frequency 9764)
# pair 635: (F) F -> (F)F (frequency 9746)
# pair 636: c(C) c(C -> c(C)c(C (frequency 9737)
# pair 637: 3) s -> 3)s (frequency 9715)
# pair 638: c2ccccc2 )cc1 -> c2ccccc2)cc1 (frequency 9711)
# pair 639: c( F)cc1 -> c(F)cc1 (frequency 9695)
# pair 640: 2)n n1 -> 2)nn1 (frequency 9681)
# pair 641: c1ccccc1 F -> c1ccccc1F (frequency 9671)
# pair 642: c(C) o -> c(C)o (frequency 9644)
# pair 643: CC(=O)N 1CC -> CC(=O)N1CC (frequency 9633)
# pair 644: c2cc (Cl)cc -> c2cc(Cl)cc (frequency 9625)
# pair 645: N1CC OCC1 -> N1CCOCC1 (frequency 9617)
# pair 646: 3CC 3)n -> 3CC3)n (frequency 9589)
# pair 647: c2 c(C)cc -> c2c(C)cc (frequency 9555)
# pair 648: c( CCC -> c(CCC (frequency 9554)
# pair 649: c2cccc 3 -> c2cccc3 (frequency 9487)
# pair 650: c2cc 3c( -> c2cc3c( (frequency 9487)
# pair 651: c2cc (C)cc -> c2cc(C)cc (frequency 9460)
# pair 652: c1 (F)cc -> c1(F)cc (frequency 9455)
# pair 653: n1 c(=O) -> n1c(=O) (frequency 9434)
# pair 654: n1 ncc -> n1ncc (frequency 9419)
# pair 655: CCC (C) -> CCC(C) (frequency 9412)
# pair 656: c1ccc( OCC -> c1ccc(OCC (frequency 9362)
# pair 657: )c( OC)cc -> )c(OC)cc (frequency 9320)
# pair 658: c2ccc( OC -> c2ccc(OC (frequency 9298)
# pair 659: s c1C -> sc1C (frequency 9277)
# pair 660: (N )=O) -> (N)=O) (frequency 9230)
# pair 661: c2cc 1 -> c2cc1 (frequency 9210)
# pair 662: c1n c(- -> c1nc(- (frequency 9161)
# pair 663: )c( F) -> )c(F) (frequency 9137)
# pair 664: n1 c(C -> n1c(C (frequency 9101)
# pair 665: n2 c(=O) -> n2c(=O) (frequency 9081)
# pair 666: c1ccccc1 Cl -> c1ccccc1Cl (frequency 9077)
# pair 667: [nH] n -> [nH]n (frequency 9041)
# pair 668: c2c( Cl)cc -> c2c(Cl)cc (frequency 9032)
# pair 669: ) O -> )O (frequency 9029)
# pair 670: c2 c[nH] -> c2c[nH] (frequency 9020)
# pair 671: O= C1 -> O=C1 (frequency 9002)
# pair 672: OC (C -> OC(C (frequency 8998)
# pair 673: N(C)C (=O)C -> N(C)C(=O)C (frequency 8988)
# pair 674: c2n o -> c2no (frequency 8986)
# pair 675: c1cc (F) -> c1cc(F) (frequency 8982)
# pair 676: c3 o -> c3o (frequency 8965)
# pair 677: c1n c2ccccc2 -> c1nc2ccccc2 (frequency 8964)
# pair 678: c2 )CC -> c2)CC (frequency 8963)
# pair 679: (C) CCC -> (C)CCC (frequency 8922)
# pair 680: ) s1 -> )s1 (frequency 8894)
# pair 681: c( O -> c(O (frequency 8882)
# pair 682: (NC(=O) NC -> (NC(=O)NC (frequency 8877)
# pair 683: (=O) CC -> (=O)CC (frequency 8869)
# pair 684: c2 on -> c2on (frequency 8864)
# pair 685: c1cc sc1 -> c1ccsc1 (frequency 8859)
# pair 686: Cc1cc (C) -> Cc1cc(C) (frequency 8859)
# pair 687: c3cc cnc3 -> c3cccnc3 (frequency 8834)
# pair 688: c2c( OC)cc -> c2c(OC)cc (frequency 8818)
# pair 689: CC N(C -> CCN(C (frequency 8803)
# pair 690: 2)cc cc1 -> 2)cccc1 (frequency 8802)
# pair 691: NC(=O) C1 -> NC(=O)C1 (frequency 8770)
# pair 692: )C (C -> )C(C (frequency 8740)
# pair 693: C N(CC -> CN(CC (frequency 8713)
# pair 694: CCC 1C -> CCC1C (frequency 8700)
# pair 695: N(C(=O) CC -> N(C(=O)CC (frequency 8692)
# pair 696: c2 c(C)n -> c2c(C)n (frequency 8691)
# pair 697: NC(=O) CO -> NC(=O)CO (frequency 8689)
# pair 698: c2c( N -> c2c(N (frequency 8685)
# pair 699: c1 (C(=O)N -> c1(C(=O)N (frequency 8685)
# pair 700: )c(OC )c1 -> )c(OC)c1 (frequency 8670)
# pair 701: (Cl ) -> (Cl) (frequency 8655)
# pair 702: c2cc (C) -> c2cc(C) (frequency 8652)
# pair 703: c( NC( -> c(NC( (frequency 8603)
# pair 704: cc c1C -> ccc1C (frequency 8584)
# pair 705: Cc1cc (C -> Cc1cc(C (frequency 8582)
# pair 706: )n n -> )nn (frequency 8553)
# pair 707: CC NC(=O)C -> CCNC(=O)C (frequency 8550)
# pair 708: c2cc (OC -> c2cc(OC (frequency 8543)
# pair 709: (F)(F) F)cc1 -> (F)(F)F)cc1 (frequency 8538)
# pair 710: ( S(=O)(=O)N -> (S(=O)(=O)N (frequency 8535)
# pair 711: 2 1 -> 21 (frequency 8503)
# pair 712: )CC 2) -> )CC2) (frequency 8442)
# pair 713: 3) CC1 -> 3)CC1 (frequency 8414)
# pair 714: NC 1 -> NC1 (frequency 8407)
# pair 715: c( OC)cc -> c(OC)cc (frequency 8400)
# pair 716: F C -> FC (frequency 8389)
# pair 717: 2)=O) C -> 2)=O)C (frequency 8383)
# pair 718: C c1cs -> Cc1cs (frequency 8354)
# pair 719: C N(C) -> CN(C) (frequency 8324)
# pair 720: c1 (OC -> c1(OC (frequency 8322)
# pair 721: c2cc cn -> c2cccn (frequency 8320)
# pair 722: c(- c3ccccc3 -> c(-c3ccccc3 (frequency 8314)
# pair 723: c(=O) [nH]1 -> c(=O)[nH]1 (frequency 8304)
# pair 724: C(=O) (N -> C(=O)(N (frequency 8302)
# pair 725: (C) =O -> (C)=O (frequency 8298)
# pair 726: c2cccc (C) -> c2cccc(C) (frequency 8288)
# pair 727: c1ccccc1 )C -> c1ccccc1)C (frequency 8277)
# pair 728: (=O)N CC -> (=O)NCC (frequency 8270)
# pair 729: c1ccc( Br)cc1 -> c1ccc(Br)cc1 (frequency 8246)
# pair 730: 3 =O) -> 3=O) (frequency 8236)
# pair 731: c(S CC(=O)N -> c(SCC(=O)N (frequency 8211)
# pair 732: c1 (=O) -> c1(=O) (frequency 8208)
# pair 733: c1n cn -> c1ncn (frequency 8168)
# pair 734: c(C (F)(F)F) -> c(C(F)(F)F) (frequency 8109)
# pair 735: c2n c3ccccc3 -> c2nc3ccccc3 (frequency 8078)
# pair 736: c1ccc(C #N)cc1 -> c1ccc(C#N)cc1 (frequency 8072)
# pair 737: NC (NC -> NC(NC (frequency 8070)
# pair 738: 2 c1 -> 2c1 (frequency 8062)
# pair 739: (Br )c1 -> (Br)c1 (frequency 8058)
# pair 740: )=O) CC1 -> )=O)CC1 (frequency 8052)
# pair 741: n2 c( -> n2c( (frequency 8023)
# pair 742: #N ) -> #N) (frequency 8023)
# pair 743: c2ccccc2 Cl -> c2ccccc2Cl (frequency 8022)
# pair 744: (NC (C)=O) -> (NC(C)=O) (frequency 8022)
# pair 745: CCOC (=O)C -> CCOC(=O)C (frequency 8013)
# pair 746: OC (=O)C -> OC(=O)C (frequency 8008)
# pair 747: CCC NC(=O) -> CCCNC(=O) (frequency 7980)
# pair 748: ) (=O) -> )(=O) (frequency 7934)
# pair 749: c3cccc n3 -> c3ccccn3 (frequency 7921)
# pair 750: o c1 -> oc1 (frequency 7910)
# pair 751: c1ccccc1 - -> c1ccccc1- (frequency 7901)
# pair 752: CC1 CCC -> CC1CCC (frequency 7900)
# pair 753: 2 ( -> 2( (frequency 7900)
# pair 754: C c1ccc(C(=O)N -> Cc1ccc(C(=O)N (frequency 7898)
# pair 755: c1c(C (N -> c1c(C(N (frequency 7887)
# pair 756: c2cc n -> c2ccn (frequency 7879)
# pair 757: cc n1 -> ccn1 (frequency 7873)
# pair 758: (C (F)(F)F) -> (C(F)(F)F) (frequency 7856)
# pair 759: Cc1cc (C(=O)N -> Cc1cc(C(=O)N (frequency 7830)
# pair 760: c3ccccc3 C -> c3ccccc3C (frequency 7826)
# pair 761: Cc1cc (C)n -> Cc1cc(C)n (frequency 7795)
# pair 762: c2ccc(F)cc 2) -> c2ccc(F)cc2) (frequency 7793)
# pair 763: C c1ccc(- -> Cc1ccc(- (frequency 7788)
# pair 764: c2ncc cn -> c2ncccn (frequency 7782)
# pair 765: c2cn n(C) -> c2cnn(C) (frequency 7716)
# pair 766: CC n1cc -> CCn1cc (frequency 7715)
# pair 767: (C (NC -> (C(NC (frequency 7713)
# pair 768: NC(=O)C (C) -> NC(=O)C(C) (frequency 7693)
# pair 769: OC )C -> OC)C (frequency 7683)
# pair 770: n2 cccc -> n2cccc (frequency 7676)
# pair 771: (=O)N 1CCC -> (=O)N1CCC (frequency 7671)
# pair 772: CCN 1CC -> CCN1CC (frequency 7650)
# pair 773: N( S(=O)(=O) -> N(S(=O)(=O) (frequency 7626)
# pair 774: 2CC (=O)N -> 2CC(=O)N (frequency 7622)
# pair 775: (C (=O) -> (C(=O) (frequency 7622)
# pair 776: 2CC N(C(=O) -> 2CCN(C(=O) (frequency 7619)
# pair 777: N(C (N -> N(C(N (frequency 7618)
# pair 778: OC )n -> OC)n (frequency 7617)
# pair 779: c2n c(C) -> c2nc(C) (frequency 7593)
# pair 780: )c2 ) -> )c2) (frequency 7579)
# pair 781: )c(Cl )c1 -> )c(Cl)c1 (frequency 7566)
# pair 782: c2cccc (OC -> c2cccc(OC (frequency 7563)
# pair 783: (C)C (=O) -> (C)C(=O) (frequency 7558)
# pair 784: NC(=O)N CC -> NC(=O)NCC (frequency 7547)
# pair 785: (C (=O)OC -> (C(=O)OC (frequency 7547)
# pair 786: 3 )=O)cc -> 3)=O)cc (frequency 7534)
# pair 787: )CC CC -> )CCCC (frequency 7534)
# pair 788: c1cc(Cl)cc c1 -> c1cc(Cl)ccc1 (frequency 7514)
# pair 789: c( NC(C -> c(NC(C (frequency 7510)
# pair 790: o c1C -> oc1C (frequency 7499)
# pair 791: c2 )C -> c2)C (frequency 7497)
# pair 792: c2cc (- -> c2cc(- (frequency 7427)
# pair 793: c1s ccc1 -> c1sccc1 (frequency 7423)
# pair 794: S c2nn -> Sc2nn (frequency 7390)
# pair 795: c2s ccc2 -> c2sccc2 (frequency 7377)
# pair 796: )=O) =O) -> )=O)=O) (frequency 7365)
# pair 797: c1n [nH] -> c1n[nH] (frequency 7364)
# pair 798: c2 )cc -> c2)cc (frequency 7361)
# pair 799: [nH] c1 -> [nH]c1 (frequency 7361)
# pair 800: )c2 C -> )c2C (frequency 7332)
# pair 801: c1n cccc1 -> c1ncccc1 (frequency 7329)
# pair 802: 2)=O) CC1 -> 2)=O)CC1 (frequency 7323)
# pair 803: c(CC )n -> c(CC)n (frequency 7321)
# pair 804: Cc1n n(C) -> Cc1nn(C) (frequency 7317)
# pair 805: )cc cc2 -> )cccc2 (frequency 7317)
# pair 806: 2=O) cc1 -> 2=O)cc1 (frequency 7316)
# pair 807: 2)cc1 C -> 2)cc1C (frequency 7303)
# pair 808: 2)=O) ccc1 -> 2)=O)ccc1 (frequency 7299)
# pair 809: )C (=O)NC -> )C(=O)NC (frequency 7288)
# pair 810: (C)(C)C )n -> (C)(C)C)n (frequency 7284)
# pair 811: c1cc (=O) -> c1cc(=O) (frequency 7282)
# pair 812: Cc1n c(C -> Cc1nc(C (frequency 7282)
# pair 813: 2) CCC1 -> 2)CCC1 (frequency 7270)
# pair 814: N(C (=O)NC -> N(C(=O)NC (frequency 7254)
# pair 815: N 1CCC -> N1CCC (frequency 7239)
# pair 816: c2 c3c( -> c2c3c( (frequency 7229)
# pair 817: c2n c(-c3cc -> c2nc(-c3cc (frequency 7224)
# pair 818: c1cccc (NC(=O) -> c1cccc(NC(=O) (frequency 7208)
# pair 819: c3cccc c2 -> c3ccccc2 (frequency 7201)
# pair 820: c3cc ncc -> c3ccncc (frequency 7196)
# pair 821: c12 cc -> c12cc (frequency 7164)
# pair 822: c3 [nH] -> c3[nH] (frequency 7145)
# pair 823: Cc1n n -> Cc1nn (frequency 7139)
# pair 824: c1cc( Br -> c1cc(Br (frequency 7124)
# pair 825: c1ccc(F) c(F)c1 -> c1ccc(F)c(F)c1 (frequency 7108)
# pair 826: c2n [nH] -> c2n[nH] (frequency 7092)
# pair 827: c(C) c(C) -> c(C)c(C) (frequency 7075)
# pair 828: c1ccc( NC(=O) -> c1ccc(NC(=O) (frequency 7057)
# pair 829: )=O) ccc1 -> )=O)ccc1 (frequency 7048)
# pair 830: c1 (S -> c1(S (frequency 7046)
# pair 831: C (CC -> C(CC (frequency 7039)
# pair 832: ) [nH] -> )[nH] (frequency 7009)
# pair 833: c2cc s -> c2ccs (frequency 7003)
# pair 834: 3 cccc -> 3cccc (frequency 6993)
# pair 835: CO c1ccc(- -> COc1ccc(- (frequency 6988)
# pair 836: C S -> CS (frequency 6962)
# pair 837: c2 c(C -> c2c(C (frequency 6951)
# pair 838: CO c1cccc(C -> COc1cccc(C (frequency 6946)
# pair 839: ( c2ccccc2 -> (c2ccccc2 (frequency 6930)
# pair 840: (C) N -> (C)N (frequency 6910)
# pair 841: S(=O) (C)=O) -> S(=O)(C)=O) (frequency 6903)
# pair 842: N1C (=O)C -> N1C(=O)C (frequency 6902)
# pair 843: CCC (N -> CCC(N (frequency 6901)
# pair 844: )cc 2) -> )cc2) (frequency 6898)
# pair 845: n2cn cn -> n2cncn (frequency 6896)
# pair 846: c3cc co -> c3ccco (frequency 6887)
# pair 847: (C)C )CC -> (C)C)CC (frequency 6869)
# pair 848: C = -> C= (frequency 6861)
# pair 849: n 4 -> n4 (frequency 6852)
# pair 850: c3ccc( Cl)cc -> c3ccc(Cl)cc (frequency 6851)
# pair 851: )c1 cn -> )c1cn (frequency 6850)
# pair 852: N2C (=O) -> N2C(=O) (frequency 6848)
# pair 853: n cc1 -> ncc1 (frequency 6811)
# pair 854: 3) n1 -> 3)n1 (frequency 6797)
# pair 855: c1cccc (C(=O)N -> c1cccc(C(=O)N (frequency 6782)
# pair 856: c2cc (N -> c2cc(N (frequency 6779)
# pair 857: CCO 1 -> CCO1 (frequency 6730)
# pair 858: c( Br -> c(Br (frequency 6726)
# pair 859: nn (C) -> nn(C) (frequency 6716)
# pair 860: c2n c(- -> c2nc(- (frequency 6713)
# pair 861: ) (N -> )(N (frequency 6712)
# pair 862: )c2 )c1 -> )c2)c1 (frequency 6705)
# pair 863: n cn -> ncn (frequency 6701)
# pair 864: cccc c1 -> ccccc1 (frequency 6700)
# pair 865: NC (CC -> NC(CC (frequency 6696)
# pair 866: 3 )C1 -> 3)C1 (frequency 6685)
# pair 867: nc1 - -> nc1- (frequency 6679)
# pair 868: 2CC 2)c1 -> 2CC2)c1 (frequency 6675)
# pair 869: 2CC 2)cc1 -> 2CC2)cc1 (frequency 6663)
# pair 870: c(=O) cc -> c(=O)cc (frequency 6641)
# pair 871: (C 1 -> (C1 (frequency 6635)
# pair 872: ) c(C) -> )c(C) (frequency 6619)
# pair 873: c( NC(=O)c2cc -> c(NC(=O)c2cc (frequency 6613)
# pair 874: CO c1ccccc1C -> COc1ccccc1C (frequency 6600)
# pair 875: c3n cccc -> c3ncccc (frequency 6574)
# pair 876: OC 2 -> OC2 (frequency 6553)
# pair 877: 2) cs1 -> 2)cs1 (frequency 6527)
# pair 878: )=O) C1 -> )=O)C1 (frequency 6527)
# pair 879: c2c(F)cc cc2 -> c2c(F)cccc2 (frequency 6501)
# pair 880: c1cc (C)cc -> c1cc(C)cc (frequency 6492)
# pair 881: n2cc nc2 -> n2ccnc2 (frequency 6477)
# pair 882: )n 2 -> )n2 (frequency 6465)
# pair 883: cc 3 -> cc3 (frequency 6455)
# pair 884: c1c( OC -> c1c(OC (frequency 6451)
# pair 885: ) ( -> )( (frequency 6444)
# pair 886: (C) OC(C)C -> (C)OC(C)C (frequency 6434)
# pair 887: (CC CC -> (CCCC (frequency 6428)
# pair 888: n1cc cn1 -> n1cccn1 (frequency 6418)
# pair 889: (C#N )c1 -> (C#N)c1 (frequency 6416)
# pair 890: CCC (=O)NC -> CCC(=O)NC (frequency 6409)
# pair 891: c1ncc s1 -> c1nccs1 (frequency 6382)
# pair 892: c(C(=O)N CC -> c(C(=O)NCC (frequency 6343)
# pair 893: ) (=O)=O -> )(=O)=O (frequency 6338)
# pair 894: c1cn n(C) -> c1cnn(C) (frequency 6329)
# pair 895: C c1cccc(C -> Cc1cccc(C (frequency 6316)
# pair 896: 4 )C -> 4)C (frequency 6316)
# pair 897: c(S CC -> c(SCC (frequency 6315)
# pair 898: n c3 -> nc3 (frequency 6306)
# pair 899: F )C -> F)C (frequency 6305)
# pair 900: c1cc(C) ccc1 -> c1cc(C)ccc1 (frequency 6302)
# pair 901: (CCC (=O)N -> (CCC(=O)N (frequency 6287)
# pair 902: c1ccc(C (N -> c1ccc(C(N (frequency 6255)
# pair 903: )c2 )cc1 -> )c2)cc1 (frequency 6254)
# pair 904: c2 )C1 -> c2)C1 (frequency 6240)
# pair 905: c( CC(=O)N -> c(CC(=O)N (frequency 6219)
# pair 906: c2ccccc2 n1 -> c2ccccc2n1 (frequency 6218)
# pair 907: 2)=O) C1 -> 2)=O)C1 (frequency 6216)
# pair 908: c1c(Cl)cc cc1 -> c1c(Cl)cccc1 (frequency 6209)
# pair 909: c2c(C) cccc -> c2c(C)cccc (frequency 6207)
# pair 910: )=O) n -> )=O)n (frequency 6204)
# pair 911: )n n1 -> )nn1 (frequency 6150)
# pair 912: 2) nn -> 2)nn (frequency 6132)
# pair 913: c1 (Cl)cc -> c1(Cl)cc (frequency 6125)
# pair 914: NC 2 -> NC2 (frequency 6123)
# pair 915: (CC (=O)NC -> (CC(=O)NC (frequency 6117)
# pair 916: c1ccccc1 F) -> c1ccccc1F) (frequency 6113)
# pair 917: S(N )(=O)=O) -> S(N)(=O)=O) (frequency 6112)
# pair 918: c2cc(F)cc c2 -> c2cc(F)ccc2 (frequency 6110)
# pair 919: c1cc (C(N -> c1cc(C(N (frequency 6106)
# pair 920: C (NC -> C(NC (frequency 6104)
# pair 921: ( F)cc1 -> (F)cc1 (frequency 6098)
# pair 922: c1n c(-c2cc -> c1nc(-c2cc (frequency 6079)
# pair 923: c2cc c(-n3 -> c2ccc(-n3 (frequency 6078)
# pair 924: C c1o -> Cc1o (frequency 6074)
# pair 925: c1cc2 cccc -> c1cc2cccc (frequency 6063)
# pair 926: (C NC(=O) -> (CNC(=O) (frequency 6056)
# pair 927: S(=O)(=O)N 1CC -> S(=O)(=O)N1CC (frequency 6034)
# pair 928: 2) =O -> 2)=O (frequency 6030)
# pair 929: c1cc2c(cc1 ) -> c1cc2c(cc1) (frequency 6009)
# pair 930: S(=O) (NC -> S(=O)(NC (frequency 6002)
# pair 931: c(C 2CC -> c(C2CC (frequency 5985)
# pair 932: )N CC -> )NCC (frequency 5972)
# pair 933: c(N CC -> c(NCC (frequency 5960)
# pair 934: O (C) -> O(C) (frequency 5960)
# pair 935: cc (- -> cc(- (frequency 5952)
# pair 936: N 2 -> N2 (frequency 5950)
# pair 937: c1ccc(O )cc1 -> c1ccc(O)cc1 (frequency 5948)
# pair 938: c1cc cn -> c1cccn (frequency 5932)
# pair 939: c1 (OC)cc -> c1(OC)cc (frequency 5932)
# pair 940: (CO )C -> (CO)C (frequency 5923)
# pair 941: c2ncc s -> c2nccs (frequency 5920)
# pair 942: c2ccccc2 )C1 -> c2ccccc2)C1 (frequency 5920)
# pair 943: c1c2c( ccc1 -> c1c2c(ccc1 (frequency 5920)
# pair 944: c1cccc2 c1 -> c1cccc2c1 (frequency 5919)
# pair 945: c1c( OCC -> c1c(OCC (frequency 5918)
# pair 946: c2ccccc2 C1 -> c2ccccc2C1 (frequency 5896)
# pair 947: CO c1cc(C -> COc1cc(C (frequency 5892)
# pair 948: n3 cn -> n3cn (frequency 5891)
# pair 949: NC(=O)N 1CC -> NC(=O)N1CC (frequency 5878)
# pair 950: 4 )CC -> 4)CC (frequency 5868)
# pair 951: c1cn n(- -> c1cnn(- (frequency 5866)
# pair 952: c1ccc( S(=O)(=O)N -> c1ccc(S(=O)(=O)N (frequency 5866)
# pair 953: c( Cl)cc -> c(Cl)cc (frequency 5857)
# pair 954: CC(C) O -> CC(C)O (frequency 5857)
# pair 955: c1 (CC -> c1(CC (frequency 5851)
# pair 956: c1c( F) -> c1c(F) (frequency 5848)
# pair 957: c1cccc (C)c1 -> c1cccc(C)c1 (frequency 5829)
# pair 958: c2ccc( OCC -> c2ccc(OCC (frequency 5821)
# pair 959: N(C (C)=O) -> N(C(C)=O) (frequency 5818)
# pair 960: c2cc c(C) -> c2ccc(C) (frequency 5798)
# pair 961: c(OC )cc1 -> c(OC)cc1 (frequency 5792)
# pair 962: c2c( c1 -> c2c(c1 (frequency 5790)
# pair 963: c1n nn -> c1nnn (frequency 5790)
# pair 964: (C) NC(=O) -> (C)NC(=O) (frequency 5784)
# pair 965: 2) (=O)=O) -> 2)(=O)=O) (frequency 5774)
# pair 966: O=C(C O -> O=C(CO (frequency 5745)
# pair 967: c2ccc(F) c(F) -> c2ccc(F)c(F) (frequency 5738)
# pair 968: CC1 CCCO1 -> CC1CCCO1 (frequency 5735)
# pair 969: c3 ) -> c3) (frequency 5734)
# pair 970: c(C (NC -> c(C(NC (frequency 5729)
# pair 971: c(N )cc -> c(N)cc (frequency 5726)
# pair 972: S 2 -> S2 (frequency 5716)
# pair 973: CO c1ccc(C(=O)N -> COc1ccc(C(=O)N (frequency 5715)
# pair 974: c1 co -> c1co (frequency 5711)
# pair 975: 2)cc1 OC -> 2)cc1OC (frequency 5703)
# pair 976: c3cc cs -> c3cccs (frequency 5684)
# pair 977: CCN 1 -> CCN1 (frequency 5670)
# pair 978: (C)C )n1 -> (C)C)n1 (frequency 5667)
# pair 979: 2CC OC -> 2CCOC (frequency 5665)
# pair 980: c1cc (C)n -> c1cc(C)n (frequency 5657)
# pair 981: (CO ) -> (CO) (frequency 5643)
# pair 982: C c1c( -> Cc1c( (frequency 5641)
# pair 983: c2cccc (N -> c2cccc(N (frequency 5639)
# pair 984: c2n nn -> c2nnn (frequency 5628)
# pair 985: c1ccccc1 OC -> c1ccccc1OC (frequency 5627)
# pair 986: (C (C)C) -> (C(C)C) (frequency 5622)
# pair 987: c3ccccc3 )CC -> c3ccccc3)CC (frequency 5611)
# pair 988: CC (O -> CC(O (frequency 5609)
# pair 989: C1 ( -> C1( (frequency 5608)
# pair 990: N(CC O -> N(CCO (frequency 5603)
# pair 991: (C#N )cc -> (C#N)cc (frequency 5603)
# pair 992: c(=O) o -> c(=O)o (frequency 5589)
# pair 993: c1ccc(C (=O)NC -> c1ccc(C(=O)NC (frequency 5579)
# pair 994: S CC(=O)N -> SCC(=O)N (frequency 5575)
# pair 995: c1cn ccc1 -> c1cnccc1 (frequency 5573)
# pair 996: c2n (C) -> c2n(C) (frequency 5570)
# pair 997: c2cc c(C#N)cc -> c2ccc(C#N)cc (frequency 5569)
# pair 998: (C)C 1 -> (C)C1 (frequency 5538)
# pair 999: c2C )cc1 -> c2C)cc1 (frequency 5532)
# pair 1000: CO c1ccc(OC -> COc1ccc(OC (frequency 5532)
# pair 1001: c2cn cc -> c2cncc (frequency 5530)
# pair 1002: (F)(F)F) c1 -> (F)(F)F)c1 (frequency 5525)
# pair 1003: c3n cn -> c3ncn (frequency 5504)
# pair 1004: C (OC -> C(OC (frequency 5479)
# pair 1005: c1o ccc1 -> c1occc1 (frequency 5458)
# pair 1006: 3)n o -> 3)no (frequency 5451)
# pair 1007: 2) cn -> 2)cn (frequency 5449)
# pair 1008: c( NC(=O)N -> c(NC(=O)N (frequency 5431)
# pair 1009: (C ( -> (C( (frequency 5413)
# pair 1010: Cc1n [nH] -> Cc1n[nH] (frequency 5409)
# pair 1011: )CC CC2 -> )CCCC2 (frequency 5404)
# pair 1012: c2o ccc2 -> c2occc2 (frequency 5401)
# pair 1013: 3) cn -> 3)cn (frequency 5387)
# pair 1014: S(C) (=O)=O -> S(C)(=O)=O (frequency 5383)
# pair 1015: O=C (CCC -> O=C(CCC (frequency 5382)
# pair 1016: c1n cccc1C -> c1ncccc1C (frequency 5380)
# pair 1017: C c1c(C -> Cc1c(C (frequency 5377)
# pair 1018: CC1 CC1 -> CC1CC1 (frequency 5370)
# ...
# pair 1832: CC1 )C -> CC1)C (frequency 2435)
# pair 1833: (N S(=O)(=O) -> (NS(=O)(=O) (frequency 2433)
# pair 1834: (N 2CC -> (N2CC (frequency 2433)
# pair 1835: c(-c3cc cs -> c(-c3cccs (frequency 2432)
# pair 1836: Cc1cc (- -> Cc1cc(- (frequency 2432)
# pair 1837: CCO c1ccc( -> CCOc1ccc( (frequency 2429)
# pair 1838: cn c4 -> cnc4 (frequency 2427)
# pair 1839: c2ncccn 2)CC1 -> c2ncccn2)CC1 (frequency 2426)
# pair 1840: 2CCOCC 2)cc1 -> 2CCOCC2)cc1 (frequency 2425)
# pair 1841: c1cc(C) on1 -> c1cc(C)on1 (frequency 2423)
# pair 1842: c2) (=O)=O) -> c2)(=O)=O) (frequency 2421)
# pair 1843: O= c1 -> O=c1 (frequency 2421)
# pair 1844: ) c1ccc(F)cc1 -> )c1ccc(F)cc1 (frequency 2421)
# pair 1845: c2 s1 -> c2s1 (frequency 2418)
# pair 1846: c3ncccc 3 -> c3ncccc3 (frequency 2417)
# pair 1847: c1c(C (=O)NC -> c1c(C(=O)NC (frequency 2417)
# pair 1848: c1n (C)n -> c1n(C)n (frequency 2414)
# pair 1849: (OC )cc1 -> (OC)cc1 (frequency 2414)
# pair 1850: (- c2ccccc2)n1 -> (-c2ccccc2)n1 (frequency 2414)
# pair 1851: 2 OCC -> 2OCC (frequency 2413)
# pair 1852: c1ccccc1 O -> c1ccccc1O (frequency 2412)
# pair 1853: c1c( NC(C -> c1c(NC(C (frequency 2412)
# pair 1854: Sc1n nn -> Sc1nnn (frequency 2411)
# pair 1855: )=O) cccc1 -> )=O)cccc1 (frequency 2411)
# pair 1856: c2n c(N -> c2nc(N (frequency 2409)
# pair 1857: c2 )=O)cc -> c2)=O)cc (frequency 2408)
# pair 1858: OC 1C -> OC1C (frequency 2405)
# pair 1859: c2cccc n2)cc1 -> c2ccccn2)cc1 (frequency 2402)
# pair 1860: c1ccccc1 Br -> c1ccccc1Br (frequency 2400)
# pair 1861: )C )C -> )C)C (frequency 2400)
# pair 1862: 2C OCC -> 2COCC (frequency 2399)
# pair 1863: (=O)N1CC N( -> (=O)N1CCN( (frequency 2395)
# pair 1864: C (C)(C) -> C(C)(C) (frequency 2393)
# pair 1865: )=O) s -> )=O)s (frequency 2393)
# pair 1866: c2nc3ccccc3 [nH] -> c2nc3ccccc3[nH] (frequency 2391)
# pair 1867: c3cc 4c( -> c3cc4c( (frequency 2387)
# pair 1868: c(C N2CC -> c(CN2CC (frequency 2387)
# pair 1869: )n cc1 -> )ncc1 (frequency 2384)
# pair 1870: (C(N )=O)CC -> (C(N)=O)CC (frequency 2384)
# pair 1871: Cc1cccc (NC(=O)C -> Cc1cccc(NC(=O)C (frequency 2381)
# pair 1872: (CO )CC -> (CO)CC (frequency 2377)
# pair 1873: c(C(N CC -> c(C(NCC (frequency 2374)
# pair 1874: c1c( NC(=O) -> c1c(NC(=O) (frequency 2369)
# pair 1875: c1cccc (CC -> c1cccc(CC (frequency 2368)
# pair 1876: (C)C) s -> (C)C)s (frequency 2367)
# pair 1877: c1cc(F) c(F)cc1 -> c1cc(F)c(F)cc1 (frequency 2365)
# pair 1878: cc 2)cc1 -> cc2)cc1 (frequency 2363)
# pair 1879: (CCO )C -> (CCO)C (frequency 2363)
# pair 1880: c2cc [nH] -> c2cc[nH] (frequency 2362)
# pair 1881: S(=O) (CC -> S(=O)(CC (frequency 2361)
# pair 1882: )=O)cc 2 -> )=O)cc2 (frequency 2359)
# pair 1883: c2n c(C)no -> c2nc(C)no (frequency 2358)
# pair 1884: 2CCC (C -> 2CCC(C (frequency 2357)
# pair 1885: c1) NC -> c1)NC (frequency 2355)
# pair 1886: # CCO -> #CCO (frequency 2355)
# pair 1887: c2 c(=O)[nH] -> c2c(=O)[nH] (frequency 2354)
# pair 1888: (C)C )=O -> (C)C)=O (frequency 2354)
# pair 1889: c3cc (Cl)cc -> c3cc(Cl)cc (frequency 2352)
# pair 1890: c2c(C)cc (C)cc -> c2c(C)cc(C)cc (frequency 2351)
# pair 1891: NC(=O) C1CCC -> NC(=O)C1CCC (frequency 2350)
# pair 1892: )=O) cn -> )=O)cn (frequency 2349)
# pair 1893: n(CC (=O)N -> n(CC(=O)N (frequency 2348)
# pair 1894: )cc2 c1 -> )cc2c1 (frequency 2346)
# pair 1895: cs c1 -> csc1 (frequency 2343)
# pair 1896: 2CCCC (C)C -> 2CCCC(C)C (frequency 2342)
# pair 1897: n1 c(SC -> n1c(SC (frequency 2339)
# pair 1898: (NC (c2cc -> (NC(c2cc (frequency 2339)
# pair 1899: c2) CCC1 -> c2)CCC1 (frequency 2338)
# pair 1900: nn 3)cc -> nn3)cc (frequency 2337)
# pair 1901: c4 cn -> c4cn (frequency 2337)
# pair 1902: c2c( O)cc -> c2c(O)cc (frequency 2337)
# pair 1903: c1 c(-c2cc -> c1c(-c2cc (frequency 2337)
# pair 1904: ) F -> )F (frequency 2337)
# pair 1905: c3cccc(F) c3 -> c3cccc(F)c3 (frequency 2336)
# pair 1906: )=O) c2 -> )=O)c2 (frequency 2336)
# pair 1907: (NC (CC -> (NC(CC (frequency 2336)
# pair 1908: )N1CC N(C -> )N1CCN(C (frequency 2332)
# pair 1909: [nH] c1=O) -> [nH]c1=O) (frequency 2331)
# pair 1910: c1c(C)cc (C) -> c1c(C)cc(C) (frequency 2329)
# pair 1911: 3)c2 C -> 3)c2C (frequency 2329)
# pair 1912: 3) s1 -> 3)s1 (frequency 2328)
# pair 1913: c2ccccc2)n o1 -> c2ccccc2)no1 (frequency 2326)
# pair 1914: c1cc( S(=O)(=O)N -> c1cc(S(=O)(=O)N (frequency 2326)
# pair 1915: c2ccccc2) s1 -> c2ccccc2)s1 (frequency 2320)
# pair 1916: CC c1ccccc1 -> CCc1ccccc1 (frequency 2320)
# pair 1917: (C)C (N -> (C)C(N (frequency 2316)
# pair 1918: c2cccc(C#N )c2 -> c2cccc(C#N)c2 (frequency 2315)
# pair 1919: c(=O)n(C) c(=O) -> c(=O)n(C)c(=O) (frequency 2313)
# pair 1920: c1c(C #N -> c1c(C#N (frequency 2309)
# pair 1921: c2c( CC -> c2c(CC (frequency 2308)
# pair 1922: COc1ccc( NC(=O)C -> COc1ccc(NC(=O)C (frequency 2308)
# pair 1923: 2)n1 C -> 2)n1C (frequency 2306)
# pair 1924: c1n 2c( -> c1n2c( (frequency 2304)
# pair 1925: C (NC( -> C(NC( (frequency 2301)
# pair 1926: n2 c(C) -> n2c(C) (frequency 2295)
# pair 1927: C1C OCC -> C1COCC (frequency 2295)
# pair 1928: (C)C )CC1 -> (C)C)CC1 (frequency 2292)
# pair 1929: n3 cc -> n3cc (frequency 2291)
# pair 1930: 2CCCC 2=O)cc1 -> 2CCCC2=O)cc1 (frequency 2291)
# pair 1931: 2) CCO1 -> 2)CCO1 (frequency 2290)
# pair 1932: c3cc(F)cc c3 -> c3cc(F)ccc3 (frequency 2286)
# pair 1933: 2)cc cc -> 2)cccc (frequency 2281)
# pair 1934: O=C(C NC(=O) -> O=C(CNC(=O) (frequency 2280)
# pair 1935: c2ncn c(N -> c2ncnc(N (frequency 2278)
# pair 1936: c2c( OCC -> c2c(OCC (frequency 2278)
# pair 1937: (C OC -> (COC (frequency 2278)
# pair 1938: c1c( Cl -> c1c(Cl (frequency 2277)
# pair 1939: c(C NC(=O)N -> c(CNC(=O)N (frequency 2277)
# pair 1940: c1(C (=O)NC -> c1(C(=O)NC (frequency 2276)
# pair 1941: c(=O)[nH] c(=O) -> c(=O)[nH]c(=O) (frequency 2276)
# pair 1942: Cc1cccc (NC(=O) -> Cc1cccc(NC(=O) (frequency 2276)
# pair 1943: c1ccc(Cl)cc1 Cl -> c1ccc(Cl)cc1Cl (frequency 2272)
# pair 1944: c1nc2c( s1 -> c1nc2c(s1 (frequency 2271)
# pair 1945: CC c1ccc(C -> CCc1ccc(C (frequency 2270)
# pair 1946: )o n1 -> )on1 (frequency 2269)
# pair 1947: N(C(=O) CO -> N(C(=O)CO (frequency 2266)
# pair 1948: (=O)OCC (=O)N -> (=O)OCC(=O)N (frequency 2264)
# pair 1949: c1ccco1 ) -> c1ccco1) (frequency 2261)
# pair 1950: c2ccc(F)cc 2)cc1 -> c2ccc(F)cc2)cc1 (frequency 2260)
# pair 1951: (C) cn -> (C)cn (frequency 2258)
# pair 1952: c1ncc (- -> c1ncc(- (frequency 2257)
# pair 1953: )c( O -> )c(O (frequency 2255)
# pair 1954: )=O) n1 -> )=O)n1 (frequency 2255)
# pair 1955: c3 =O) -> c3=O) (frequency 2254)
# pair 1956: C1 O -> C1O (frequency 2253)
# pair 1957: (OC )=O)C -> (OC)=O)C (frequency 2249)
# pair 1958: NC 2=O) -> NC2=O) (frequency 2248)
# pair 1959: (C (C) -> (C(C) (frequency 2248)
# pair 1960: c1cccc(C (=O)NC -> c1cccc(C(=O)NC (frequency 2246)
# pair 1961: 2CCCC 2)=O) -> 2CCCC2)=O) (frequency 2245)
# pair 1962: 2CC 2 -> 2CC2 (frequency 2245)
# pair 1963: C(N )=O -> C(N)=O (frequency 2242)
# pair 1964: c(C) cn -> c(C)cn (frequency 2241)
# pair 1965: )cc1 2 -> )cc12 (frequency 2238)
# pair 1966: )c( Br -> )c(Br (frequency 2237)
# pair 1967: c(C)n c1C -> c(C)nc1C (frequency 2230)
# pair 1968: c2 c(C(=O)N -> c2c(C(=O)N (frequency 2226)
# pair 1969: c2 c(=O) -> c2c(=O) (frequency 2226)
# pair 1970: c1cs c(- -> c1csc(- (frequency 2223)
# pair 1971: c1cccc (C(N -> c1cccc(C(N (frequency 2222)
# pair 1972: = CC1 -> =CC1 (frequency 2222)
# pair 1973: 2)cc c1=O -> 2)ccc1=O (frequency 2222)
# pair 1974: cc 2)c1 -> cc2)c1 (frequency 2221)
# pair 1975: c2cc(C) on -> c2cc(C)on (frequency 2221)
# pair 1976: CC(C) O1 -> CC(C)O1 (frequency 2221)
# pair 1977: 3)CC 2)n1 -> 3)CC2)n1 (frequency 2218)
# pair 1978: C c1ccc(-c2n -> Cc1ccc(-c2n (frequency 2217)
# pair 1979: c2n c(C)cc -> c2nc(C)cc (frequency 2216)
# pair 1980: c(C NC(=O)C -> c(CNC(=O)C (frequency 2216)
# pair 1981: (CCC O -> (CCCO (frequency 2215)
# pair 1982: c2n c(C)n -> c2nc(C)n (frequency 2211)
# pair 1983: (F)(F)F) n -> (F)(F)F)n (frequency 2207)
# pair 1984: c(C (C)=O) -> c(C(C)=O) (frequency 2206)
# pair 1985: c(C (F)(F)F)cc -> c(C(F)(F)F)cc (frequency 2205)
# pair 1986: c3ccccc3 2)c1 -> c3ccccc32)c1 (frequency 2204)
# pair 1987: S(=O) (c2cc -> S(=O)(c2cc (frequency 2204)
# pair 1988: C( OCC -> C(OCC (frequency 2204)
# pair 1989: c( S(=O)(N -> c(S(=O)(N (frequency 2203)
# pair 1990: c(C#N )c2 -> c(C#N)c2 (frequency 2200)
# pair 1991: 1CC N(C(=O) -> 1CCN(C(=O) (frequency 2200)
# pair 1992: c1c(C) cccc1C -> c1c(C)cccc1C (frequency 2199)
# pair 1993: c(C 2CCC -> c(C2CCC (frequency 2198)
# pair 1994: CC n1cn -> CCn1cn (frequency 2194)
# pair 1995: )c1 2 -> )c12 (frequency 2194)
# pair 1996: c1(C N -> c1(CN (frequency 2191)
# pair 1997: (C NC( -> (CNC( (frequency 2191)
# pair 1998: (C(=O)N 2CC -> (C(=O)N2CC (frequency 2188)
# pair 1999: Cc1n n(- -> Cc1nn(- (frequency 2186)
# pair 2000: Cc1cccc (- -> Cc1cccc(- (frequency 2186)
# pair 2001: (C)OC(C)C 1 -> (C)OC(C)C1 (frequency 2186)
# pair 2002: n1 (CC -> n1(CC (frequency 2185)
# pair 2003: )c( NC -> )c(NC (frequency 2185)
# pair 2004: 2CCOCC 2)c1 -> 2CCOCC2)c1 (frequency 2184)
# pair 2005: c1ccc(- n2cncn -> c1ccc(-n2cncn (frequency 2183)
# pair 2006: S CC(N -> SCC(N (frequency 2180)
# pair 2007: )cc ccc1 -> )ccccc1 (frequency 2180)
# pair 2008: c2 )ccc1 -> c2)ccc1 (frequency 2179)
# pair 2009: )n [nH] -> )n[nH] (frequency 2179)
# pair 2010: 2) c(OC)c1 -> 2)c(OC)c1 (frequency 2178)
# pair 2011: c2cc (C#N -> c2cc(C#N (frequency 2172)
# pair 2012: c2ccccn 2)c1 -> c2ccccn2)c1 (frequency 2170)
# pair 2013: S2 (=O)=O) -> S2(=O)=O) (frequency 2169)
# pair 2014: 2)cc1 Cl -> 2)cc1Cl (frequency 2169)
# pair 2015: N(C (NC -> N(C(NC (frequency 2168)
# pair 2016: )c( CC -> )c(CC (frequency 2168)
# pair 2017: (=O)OC (C)(C)C -> (=O)OC(C)(C)C (frequency 2164)
# pair 2018: C(C 1 -> C(C1 (frequency 2163)
# pair 2019: c2n (C -> c2n(C (frequency 2161)
# pair 2020: c3c(C) cccc -> c3c(C)cccc (frequency 2160)
# pair 2021: n3 cccc -> n3cccc (frequency 2158)
# pair 2022: c3cc o -> c3cco (frequency 2157)
# pair 2023: 2)=O) CCC1 -> 2)=O)CCC1 (frequency 2157)
# pair 2024: 2 OCCC -> 2OCCC (frequency 2157)
# pair 2025: 2)CC CCC1 -> 2)CCCCC1 (frequency 2150)
# pair 2026: c2c(F)cccc2 F) -> c2c(F)cccc2F) (frequency 2149)
# pair 2027: )c(Cl )cc1 -> )c(Cl)cc1 (frequency 2145)
# pair 2028: c1cn [nH]c1 -> c1cn[nH]c1 (frequency 2144)
# pair 2029: c3n c(C) -> c3nc(C) (frequency 2143)
# pair 2030: )N 1 -> )N1 (frequency 2141)
# pair 2031: c(- c2ccccc2)n -> c(-c2ccccc2)n (frequency 2138)
# pair 2032: c2ccc3c( c2)CC -> c2ccc3c(c2)CC (frequency 2137)
# pair 2033: 3CC 3)c2 -> 3CC3)c2 (frequency 2137)
# pair 2034: c2cn n(C -> c2cnn(C (frequency 2136)
# pair 2035: 2CCCCC 2C -> 2CCCCC2C (frequency 2135)
# pair 2036: 2)=O) n1 -> 2)=O)n1 (frequency 2135)
# pair 2037: n [nH] -> n[nH] (frequency 2129)
# pair 2038: c2[nH] c(=O) -> c2[nH]c(=O) (frequency 2129)
# pair 2039: N1C ( -> N1C( (frequency 2128)
# pair 2040: 4 CCCC -> 4CCCC (frequency 2128)
# pair 2041: )C1 =O -> )C1=O (frequency 2128)
# pair 2042: c1(C (NC -> c1(C(NC (frequency 2127)
# pair 2043: c1cccc(N )c1 -> c1cccc(N)c1 (frequency 2124)
# pair 2044: )cn 2 -> )cn2 (frequency 2124)
# pair 2045: S (C -> S(C (frequency 2121)
# pair 2046: c1ccccc1 N -> c1ccccc1N (frequency 2119)
# pair 2047: CO CC1 -> COCC1 (frequency 2119)
# pair 2048: CC c1onc(C)c1 -> CCc1onc(C)c1 (frequency 2119)
# pair 2049: (OC )c3 -> (OC)c3 (frequency 2119)
# pair 2050: (=O)NC (C)(C)C -> (=O)NC(C)(C)C (frequency 2119)
# pair 2051: ( S(=O)(=O) -> (S(=O)(=O) (frequency 2117)
# pair 2052: = NS(=O)(=O) -> =NS(=O)(=O) (frequency 2116)
# pair 2053: ) c1cccs1 -> )c1cccs1 (frequency 2116)
# pair 2054: c2cc (=O) -> c2cc(=O) (frequency 2115)
# pair 2055: NC(=O)N 1CCC -> NC(=O)N1CCC (frequency 2114)
# pair 2056: Cc1cc n -> Cc1ccn (frequency 2114)
# pair 2057: 3)C 2)c1 -> 3)C2)c1 (frequency 2111)
# pair 2058: 3)C 2) -> 3)C2) (frequency 2106)
# pair 2059: c3ccc4c( c3) -> c3ccc4c(c3) (frequency 2102)
# pair 2060: c(C)cc 2 -> c(C)cc2 (frequency 2102)
# pair 2061: (S (C)(=O)=O) -> (S(C)(=O)=O) (frequency 2100)
# pair 2062: c1 (NC( -> c1(NC( (frequency 2096)
# pair 2063: c2c1 =O -> c2c1=O (frequency 2094)
# pair 2064: c3 c(C)cc -> c3c(C)cc (frequency 2093)
# pair 2065: c2C )CC1 -> c2C)CC1 (frequency 2092)
# pair 2066: c1nn c2cccc -> c1nnc2cccc (frequency 2092)
# pair 2067: C1C N(C(=O) -> C1CN(C(=O) (frequency 2092)
# pair 2068: )c1 =O -> )c1=O (frequency 2092)
# pair 2069: c3c(cccc 3)n -> c3c(cccc3)n (frequency 2088)
# pair 2070: c2cc c(C(=O)NC -> c2ccc(C(=O)NC (frequency 2087)
# pair 2071: CO c1ccn -> COc1ccn (frequency 2087)
# pair 2072: c3ccccc3 O -> c3ccccc3O (frequency 2081)
# pair 2073: CC1C N(C -> CC1CN(C (frequency 2081)
# pair 2074: c2ccco 2) -> c2ccco2) (frequency 2079)
# pair 2075: c2cs cn -> c2cscn (frequency 2078)
# pair 2076: c(CC (N -> c(CC(N (frequency 2078)
# pair 2077: c1ccc2c(c1) OCCO -> c1ccc2c(c1)OCCO (frequency 2076)
# pair 2078: c1ccc(- n2cn -> c1ccc(-n2cn (frequency 2076)
# pair 2079: CCO c1ccc(C(=O)N -> CCOc1ccc(C(=O)N (frequency 2076)
# pair 2080: c1c(C) o -> c1c(C)o (frequency 2074)
# pair 2081: cn cn -> cncn (frequency 2073)
# pair 2082: (=O)NC 1 -> (=O)NC1 (frequency 2071)
# pair 2083: c1c( O -> c1c(O (frequency 2070)
# pair 2084: N1CC N(C(=O)C -> N1CCN(C(=O)C (frequency 2070)
# pair 2085: C(=O) (NC -> C(=O)(NC (frequency 2068)
# pair 2086: o 2)c1 -> o2)c1 (frequency 2066)
# pair 2087: Cc1ccc( N -> Cc1ccc(N (frequency 2066)
# pair 2088: c2ncccc 2C -> c2ncccc2C (frequency 2065)
# pair 2089: c1ccc(F)cc1 F) -> c1ccc(F)cc1F) (frequency 2063)
# pair 2090: (=O)N ( -> (=O)N( (frequency 2063)
# pair 2091: c2c(C) o -> c2c(C)o (frequency 2062)
# pair 2092: ) c1ccncc1 -> )c1ccncc1 (frequency 2062)
# pair 2093: c3c( OC)cc -> c3c(OC)cc (frequency 2059)
# pair 2094: c(F)cc cc1 -> c(F)cccc1 (frequency 2059)
# pair 2095: cccc c12 -> ccccc12 (frequency 2056)
# pair 2096: (F)F) c1 -> (F)F)c1 (frequency 2054)
# pair 2097: )n cn -> )ncn (frequency 2053)
# pair 2098: c2cc c[nH] -> c2ccc[nH] (frequency 2052)
# pair 2099: c(O )c1 -> c(O)c1 (frequency 2052)
# pair 2100: ) c1n -> )c1n (frequency 2052)
# pair 2101: )=O) CCC1 -> )=O)CCC1 (frequency 2051)
# pair 2102: c1 c(=O)[nH] -> c1c(=O)[nH] (frequency 2050)
# pair 2103: c2cc(C)cc c2 -> c2cc(C)ccc2 (frequency 2047)
# pair 2104: c1 (Cl -> c1(Cl (frequency 2046)
# pair 2105: (CC (C)C) -> (CC(C)C) (frequency 2046)
# pair 2106: c2ncc nc2 -> c2nccnc2 (frequency 2045)
# pair 2107: (C) CCO -> (C)CCO (frequency 2045)
# pair 2108: c2cc(F) c(F)cc -> c2cc(F)c(F)cc (frequency 2044)
# pair 2109: 2CC 2)n1 -> 2CC2)n1 (frequency 2042)
# pair 2110: )N (C)C(=O) -> )N(C)C(=O) (frequency 2042)
# pair 2111: c(=O)n(CC (=O)N -> c(=O)n(CC(=O)N (frequency 2041)
# pair 2112: N(C(=O)N CC -> N(C(=O)NCC (frequency 2041)
# pair 2113: )CC O1 -> )CCO1 (frequency 2041)
# pair 2114: c2cccc3 cc -> c2cccc3cc (frequency 2040)
# pair 2115: S (c2cc -> S(c2cc (frequency 2039)
# pair 2116: )n c(C -> )nc(C (frequency 2037)
# pair 2117: NC(=O) c2cn -> NC(=O)c2cn (frequency 2034)
# pair 2118: c2ccccc2F) CC1 -> c2ccccc2F)CC1 (frequency 2033)
# pair 2119: NC(=O)C N -> NC(=O)CN (frequency 2031)
# pair 2120: F C( -> FC( (frequency 2031)
# pair 2121: Cc1ccccc1 - -> Cc1ccccc1- (frequency 2029)
# pair 2122: CCC n1 -> CCCn1 (frequency 2029)
# pair 2123: cn n1 -> cnn1 (frequency 2028)
# pair 2124: Cc1cccc (N -> Cc1cccc(N (frequency 2028)
# pair 2125: O= S(=O)(NC -> O=S(=O)(NC (frequency 2027)
# pair 2126: CC1CC CC1 -> CC1CCCC1 (frequency 2027)
# pair 2127: c( CCO -> c(CCO (frequency 2023)
# pair 2128: (OC ) -> (OC) (frequency 2022)
# pair 2129: c4 ncc -> c4ncc (frequency 2021)
# pair 2130: CC CCN -> CCCCN (frequency 2021)
# pair 2131: 2CCC3 (CC -> 2CCC3(CC (frequency 2018)
# pair 2132: 2CCCCC 2)c1 -> 2CCCCC2)c1 (frequency 2016)
# pair 2133: CCN(CC )C(=O)C -> CCN(CC)C(=O)C (frequency 2015)
# pair 2134: C NC(=O)N -> CNC(=O)N (frequency 2015)
# pair 2135: CCC (CC -> CCC(CC (frequency 2014)
# pair 2136: (C)C (C) -> (C)C(C) (frequency 2013)
# pair 2137: c1ccn c(OC -> c1ccnc(OC (frequency 2011)
# pair 2138: )CC CC1 -> )CCCC1 (frequency 2010)
# pair 2139: )CC 2)c1 -> )CC2)c1 (frequency 2010)
# pair 2140: (C)(C) O -> (C)(C)O (frequency 2010)
# pair 2141: c2cc 3cccc -> c2cc3cccc (frequency 2009)
# pair 2142: CC NC2 -> CCNC2 (frequency 2007)
# pair 2143: )cc1 )C -> )cc1)C (frequency 2007)
# pair 2144: Cc1cc (C(=O)NC -> Cc1cc(C(=O)NC (frequency 2005)
# pair 2145: )N1CC CCC1 -> )N1CCCCC1 (frequency 2004)
# pair 2146: c1cccc2 n -> c1cccc2n (frequency 2003)
# pair 2147: c2cccc(N )c2 -> c2cccc(N)c2 (frequency 2002)
# pair 2148: (Cl)cc c1 -> (Cl)ccc1 (frequency 2002)
# pair 2149: (=O)NC 1CC -> (=O)NC1CC (frequency 2000)
# no pair has frequency >= 2000. Stopping
# Wall time: 3h 33min 52s

# %% [markdown]
# ## SPE 결과 비교

# %%
import codecs
from SmilesPE.tokenizer import *

spe_vob= codecs.open('C:/Users/Administrator/SPE_output.txt')
spe = SPE_Tokenizer(spe_vob)

for smi in smiii:
    tokens = spe.tokenize(smi)
    print(tokens.split()) #split(); 공백을 기준으로 분리
# Out:
# ['CCC', 'S(=O)', 'c1ccc2[nH]', 'c(', '=', 'NC(=O)', 'OC)', '[nH]', 'c2c1']
# ['CC(C)(C)C', '(=O)C', '(O', 'c1ccc(Cl)cc1', ')n1', 'cc', 'nc1']
# ['C', 'c1c(Cl)cccc1', 'Nc1n', 'cccc1C', '(=O)OCC', '(O)C', 'O']
# ['Cn1', 'cnc2c1', 'c(=O)n(CC', '(O)C', 'O)', 'c(=O)n2C']
# ['CC1', 'O', 'c2ccc(Cl)cc2', 'N(CC', '(O)C', 'O', ')C1=O']
# ['CCOC(=O)', 'c1cn', 'cn1', 'C1CCC', 'c2ccccc21']
# ['COc1ccccc1', 'OC(=O)', 'O', 'c1ccccc1OC']
# ['O=C1', 'N', 'c2ccc(Cl)cc', '2C', '(c2ccccc2', 'Cl)', '=', 'NC1', 'O']
# ['C', 'N1C(=O)C', '(O', ')N', '=C(', 'c2ccccc2', 'Cl)', 'c2cc(Cl)cc', 'c21']
# ['CCC(=O)', 'c1ccc(OCC', '(O)C', 'O', ')c(OC)c1']

# %%
import codecs
from SmilesPE.tokenizer import *

spe_vob= codecs.open('C:/Users/Administrator/SPE_ChEMBL.txt')
spe = SPE_Tokenizer(spe_vob)

for smi in smiii:
    tokens = spe.tokenize(smi)
    print(tokens.split()) #split(); 공백을 기준으로 분리
# Out:
# ['CCC', 'S(=O)', 'c1ccc2[nH]', 'c(', '=', 'NC(=O)', 'OC)', '[nH]c2c1']
# ['CC(C)(C)', 'C(=O)C(', 'Oc1ccc(', 'Cl)cc1)', 'n1cc', 'nc1']
# ['Cc1c(Cl)', 'cccc1', 'Nc1n', 'cccc1', 'C(=O)OCC', '(O)', 'CO']
# ['Cn1', 'cnc2', 'c1c(=O)', 'n(', 'CC(O)', 'CO)', 'c(=O)n2', 'C']
# ['CC1', 'O', 'c2ccc(Cl)cc2', 'N(', 'CC(O)', 'CO)', 'C1=O']
# ['CCOC(=O)', 'c1cn', 'cn1', 'C1', 'CCC', 'c2ccccc21']
# ['COc1ccccc1', 'O', 'C(=O)O', 'c1ccccc1', 'OC']
# ['O=C1N', 'c2ccc(Cl)cc2', 'C(', 'c2ccccc2Cl)', '=N', 'C1O']
# ['CN1C(=O)', 'C(O)', 'N=C(', 'c2ccccc2Cl)', 'c2cc(Cl)cc', 'c21']
# ['CCC(=O)', 'c1ccc(OCC', '(O)', 'CO)', 'c(OC)c1']
